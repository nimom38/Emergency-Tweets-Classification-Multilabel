# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ced5b26b-6b31-460c-adc1-800b9fd7a724" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ced5b26b-6b31-460c-adc1-800b9fd7a724">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving TRECIS-CTIT-H-074.csv to TRECIS-CTIT-H-074.csv
# Saving TRECIS-CTIT-H-073.csv to TRECIS-CTIT-H-073.csv
# Saving TRECIS-CTIT-H-067.csv to TRECIS-CTIT-H-067.csv
# Saving TRECIS-CTIT-H-072.csv to TRECIS-CTIT-H-072.csv
# Saving TRECIS-CTIT-H-071.csv to TRECIS-CTIT-H-071.csv
# Saving TRECIS-CTIT-H-069.csv to TRECIS-CTIT-H-069.csv
# Saving TRECIS-CTIT-H-070.csv to TRECIS-CTIT-H-070.csv
# Saving TRECIS-CTIT-H-068.csv to TRECIS-CTIT-H-068.csv
# Saving TRECIS-CTIT-H-075.csv to TRECIS-CTIT-H-075.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
from google.colab import files
#uploaded = files.upload()

# %%
import pandas as pd

# %%
clss = [
        "GoodsServices",
"SearchAndRescue",
"InformationWanted",
"Volunteer",
"Donations",
"MovePeople",
"FirstPartyObservation",
"ThirdPartyObservation",
"Weather",
"EmergingThreats",
"NewSubEvent",
"MultimediaShare",
"ServiceAvailable",
"Factoid",
"Official",
"News",
"CleanUp",
"Hashtags",
"OriginalEvent",
"ContextualInformation",
"Advice",
"Sentiment",
"Discussion",
"Irrelevant",
"Location"
]

# %%
def func(a, b):
  for index, value in a.items():
    huhu = value
    if str(int(huhu)) == str(int(b)):
     # print(huhu, b)
      return True
  return False

# %%
def func2(a, b):
  for index, value in a.items():
    huhu = value
    if str(int(huhu)) == str(int(b)):
      return index

# %%
def check(a):
  a = str(a)
  for ch in a:
    if ch >= '0' and ch <= '9':
      continue
    if ch == '.':
      continue
    return False
  return True

# %%
import json
import math
import numpy
cc = 0
combo = pd.read_csv('/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/Combined labels.csv')
print(combo.columns)
hoho = combo['postID']
store = []
file_names = [
              #'/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/8. TestSet_2020_B_Covid/TRECIS-CTIT-H-067.csv',
              #'/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/8. TestSet_2020_B_Covid/TRECIS-CTIT-H-068.csv',
              #'/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/8. TestSet_2020_B_Covid/TRECIS-CTIT-H-069.csv',
              #'/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/8. TestSet_2020_B_Covid/TRECIS-CTIT-H-070.csv',
              #'/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/8. TestSet_2020_B_Covid/TRECIS-CTIT-H-071.csv',
              #'/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/8. TestSet_2020_B_Covid/TRECIS-CTIT-H-072.csv',
              #'/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/8. TestSet_2020_B_Covid/TRECIS-CTIT-H-073.csv',
              #'/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/8. TestSet_2020_B_Covid/TRECIS-CTIT-H-074.csv',
              '/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/8. TestSet_2020_B_Covid/TRECIS-CTIT-H-075.csv'
]
assert len(file_names) == 1
# Out:
# Index(['postID', 'eventID', 'eventName', 'eventDescription', 'eventType',
#        'postCategories', 'postPriority'],
#       dtype='object')

# %%
for file in file_names:
  df = pd.read_csv(file)
  for row in df.itertuples(name=None):
    print(row)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
store.clear()
cc = 0
for file in file_names:
  cc += 1
  df = pd.read_csv(file)
  arr = []
  for row in df.itertuples(name=None):
    if (row[4] is None) or ((not isinstance(row[4], str)) and (math.isnan(row[4]) == True)):
      continue
    if (row[4] == "TWEETS"):
      continue
    if check(row[4]) == False:
      continue
#    if func(hoho, row[4]) == False:
#      continue
#    yap = func2(hoho, row[4])
    dic = {}
    
    dic['tweet_text'] = None
    dic['tweet_text'] = row[5]

    dic['user_verified'] = None
    if not ((row[16] is None) or ((not isinstance(row[16], str)) and (math.isnan(row[16]) == True))) and 'verified' in row[16]:
      dic['user_verified'] = int(eval(row[16])['verified'] == True)
    
    dic['user_followers'] = None
    if not ((row[16] is None) or ((not isinstance(row[16], str)) and (math.isnan(row[16]) == True))) and 'followers_count' in row[16]:
      dic['user_followers'] = int(eval(row[16])['followers_count'])
    
    dic['user_following'] = None

    dic['media'] = 0
    if not ((row[33] is None) or ((not isinstance(row[33], str)) and (math.isnan(row[33]) == True))):
      dic['media'] = int(len(row[33])>2)
    
    dic['user_statuses'] = None
    if not ((row[16] is None) or ((not isinstance(row[16], str)) and (math.isnan(row[16]) == True))) and 'statuses_count' in row[16]:
      dic['user_statuses'] = int(eval(row[16])['statuses_count'])
    
    dic['timestamp'] = None
    dic['timestamp'] = row[2]

    dic['identifier'] = str(row[4])

    dic['language'] = None
    dic['language'] = row[26]

    dic['location_metadata'] = None

    for words in clss:
      dic[words] = 0
    dic['priority_level'] = "FIND OUT"
#    hmm = int(row[6])
#    temp = []
#    temp = combo.iloc[yap, 5]
#    temp2 = ""
#    for i in range(len(temp)):
#      if (temp[i] == '[') or (temp[i] == ']') or (temp[i] == ',') or (temp[i] == '\''):
#        temp2 += ' '
#      else:
#        temp2 += temp[i]
#    temp2 = list(temp2.split())
#    for words in temp2:
#     dic[words] = 1
#    dic['priority_level'] = combo.iloc[yap, 6]
    arr.append(dic)
  df = pd.DataFrame.from_dict(arr)
  df.drop_duplicates(subset=['identifier'], keep = "first")
  df.set_index('identifier', inplace=True, drop=True)
  store.append(df)
  print(cc, file)
  print(df.shape)
  print(df.columns)
  print(df.info())
  #df.to_csv(file)
  #files.download(file)
# Out:
# 1 /content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/8. TestSet_2020_B_Covid/TRECIS-CTIT-H-075.csv
# (5143, 35)
# Index(['tweet_text', 'user_verified', 'user_followers', 'user_following',
#        'media', 'user_statuses', 'timestamp', 'language', 'location_metadata',
#        'GoodsServices', 'SearchAndRescue', 'InformationWanted', 'Volunteer',
#        'Donations', 'MovePeople', 'FirstPartyObservation',
#        'ThirdPartyObservation', 'Weather', 'EmergingThreats', 'NewSubEvent',
#        'MultimediaShare', 'ServiceAvailable', 'Factoid', 'Official', 'News',
#        'CleanUp', 'Hashtags', 'OriginalEvent', 'ContextualInformation',
#        'Advice', 'Sentiment', 'Discussion', 'Irrelevant', 'Location',
#        'priority_level'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 5143 entries, 1284782910403297282 to 1286739958611316736
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ...

# %%
print(len(store))
for i in range(len(file_names)):
  yoman = file_names[i] + "______"
  print(i, yoman)
  store[i].to_csv(yoman)
  files.download(yoman)
# Out:
# 1
# 0 /content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/8. TestSet_2020_B_Covid/TRECIS-CTIT-H-075.csv______
