# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-65596e48-dc65-42d5-ba2a-0b62befb2fe3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-65596e48-dc65-42d5-ba2a-0b62befb2fe3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving TRECIS-2020A-covidlabels.json to TRECIS-2020A-covidlabels.json

# %%
import pandas as pd
import json

# %%
file_name = "TRECIS-2020A-covidlabels.json"

df = pd.read_json(file_name)
df.set_index('postID')
# Out:
#                                            eventID  ... postPriority
# postID                                              ...
# 1232019627682566144               covidNYC2020Pool  ...          Low
# 1232714049147662336  covidWashingtonState2020Pool2  ...          Low
# 1232734761048670208  covidWashingtonState2020Pool2  ...          Low
# 1232758136668332032  covidWashingtonState2020Pool2  ...          Low
# 1232782261709238272               covidNYC2020Pool  ...          Low
# ...                                            ...  ...          ...
# 1257954060633767936              covidNYC2020Pool2  ...          Low
# 1257988030780104704              covidNYC2020Pool2  ...         High
# 1257988943141797888              covidNYC2020Pool2  ...          Low
# 1258021643299020800              covidNYC2020Pool2  ...         High
# 1258036104705519616  covidWashingtonState2020Pool2  ...          Low
#
# [7575 rows x 6 columns]

# %%
from google.colab import files
df.to_csv('TRECIS-2020A-covidlabels.csv')
