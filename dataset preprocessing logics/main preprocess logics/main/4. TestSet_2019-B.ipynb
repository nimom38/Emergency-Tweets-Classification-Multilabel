# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f4b035bf-d3ea-4141-be60-2b1d79ec7344" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f4b035bf-d3ea-4141-be60-2b1d79ec7344">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving trecis2019-B-test.southAfricaFloods2019.csv to trecis2019-B-test.southAfricaFloods2019.csv
# Saving trecis2019-B-test.sandiegoSynagogueShooting2019.csv to trecis2019-B-test.sandiegoSynagogueShooting2019.csv
# Saving trecis2019-B-test.philippinesEarthquake2019.csv to trecis2019-B-test.philippinesEarthquake2019.csv
# Saving trecis2019-B-test.cycloneKenneth2019.csv to trecis2019-B-test.cycloneKenneth2019.csv
# Saving trecis2019-B-test.coloradoStemShooting2019.csv to trecis2019-B-test.coloradoStemShooting2019.csv
# Saving trecis2019-B-test.albertaWildfires2019.csv to trecis2019-B-test.albertaWildfires2019.csv

# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-30d99dee-0cd1-475d-a467-10f0b52c324e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-30d99dee-0cd1-475d-a467-10f0b52c324e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Combined labels.csv to Combined labels.csv

# %%
import pandas as pd

# %%
clss = [
        "GoodsServices",
"SearchAndRescue",
"InformationWanted",
"Volunteer",
"Donations",
"MovePeople",
"FirstPartyObservation",
"ThirdPartyObservation",
"Weather",
"EmergingThreats",
"NewSubEvent",
"MultimediaShare",
"ServiceAvailable",
"Factoid",
"Official",
"News",
"CleanUp",
"Hashtags",
"OriginalEvent",
"ContextualInformation",
"Advice",
"Sentiment",
"Discussion",
"Irrelevant",
"Location"
]

# %%
def func(a, b):
  for index, value in a.items():
    huhu = value
    if str(int(huhu)) == str(int(b)):
     # print(huhu, b)
      return True
  return False

# %%
def func2(a, b):
  for index, value in a.items():
    huhu = value
    if str(int(huhu)) == str(int(b)):
      return index

# %%
def check(a):
  a = str(a)
  for ch in a:
    if ch >= '0' and ch <= '9':
      continue
    if ch == '.':
      continue
    return False
  return True

# %%
import json
import math
import numpy
cc = 0
combo = pd.read_csv('Combined labels.csv')
print(combo.columns)
hoho = combo['postID']
store = []
file_names = [
              'trecis2019-B-test.southAfricaFloods2019.csv',
              'trecis2019-B-test.sandiegoSynagogueShooting2019.csv',
              'trecis2019-B-test.philippinesEarthquake2019.csv',
              'trecis2019-B-test.cycloneKenneth2019.csv',
              'trecis2019-B-test.coloradoStemShooting2019.csv',
              'trecis2019-B-test.albertaWildfires2019.csv'
]
assert len(file_names) == 6
# Out:
# Index(['postID', 'eventID', 'eventName', 'eventDescription', 'eventType',
#        'postCategories', 'postPriority'],
#       dtype='object')

# %%
for file in file_names:
  df = pd.read_csv(file)
  for row in df.itertuples(name=None):
    print(row)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
store.clear()
cc = 0
for file in file_names:
  cc += 1
  df = pd.read_csv(file)
  arr = []
  for row in df.itertuples(name=None):
    if (row[6] is None) or ((not isinstance(row[6], str)) and (math.isnan(row[6]) == True)):
      continue
    if (row[6] == "TWEETS"):
      continue
    if check(row[6]) == False:
      continue
    if func(hoho, row[6]) == False:
      continue
    yap = func2(hoho, row[6])
    xxx = None
    if (row[2] is not None) and (isinstance(row[2], str)):
      xxx = eval(row[2])
    dic = {}
    dic['tweet_text'] = None
    if xxx is not None:
      assert 'text' in xxx
      dic['tweet_text'] = xxx['text']
    dic['user_verified'] = None
    if xxx is not None:
      if 'user.verified' in xxx:
        dic['user_verified'] = int(xxx['user.verified']=='true')
    dic['user_followers'] = None
    if xxx is not None:
      if 'user.followersCount' in xxx:
        dic['user_followers'] = int(xxx['user.followersCount'])
      if 'user.followers_count' in xxx:
        dic['user_followers'] = int(xxx['user.followers_count'])
    dic['user_following'] = None
    dic['media'] = 0
    if xxx is not None:
      if 'mediaEntities' in xxx:
        dic['media'] = int(len(xxx['mediaEntities'])>2)
      if 'entities.media' in xxx:
        dic['media'] = int(len(xxx['entities.media'])>2)
      if 'retweeted_status.extended_entities.media' in xxx:
        dic['media'] = int(len(xxx['retweeted_status.extended_entities.media'])>2)
    dic['user_statuses'] = None
    if xxx is not None:
      if 'user.statusesCount' in xxx:
        dic['user_statuses'] = int(xxx['user.statusesCount'])
      if 'user.statuses_count' in xxx:
        dic['user_statuses'] = int(xxx['user.statuses_count'])
    dic['timestamp'] = None
    if xxx is not None:
      if 'timestamp' in xxx:
        dic['timestamp'] = xxx['timestamp']
    dic['identifier'] = str(row[6])
    dic['language'] = None
    if xxx is not None:
      if 'user.lang' in xxx:
        dic['language'] = xxx['user.lang']
    dic['location_metadata'] = None
    if xxx is not None:
      if 'place.boundingBoxCoordinates' in xxx:
        dic['location_metadata'] = xxx['place.boundingBoxCoordinates']
    for words in clss:
      dic[words] = 0
    hmm = int(row[6])
    temp = []
    temp = combo.iloc[yap, 5]
    temp2 = ""
    for i in range(len(temp)):
      if (temp[i] == '[') or (temp[i] == ']') or (temp[i] == ',') or (temp[i] == '\''):
        temp2 += ' '
      else:
        temp2 += temp[i]
    temp2 = list(temp2.split())
    for words in temp2:
      dic[words] = 1
    dic['priority_level'] = combo.iloc[yap, 6]
    arr.append(dic)
  df = pd.DataFrame.from_dict(arr)
  df.drop_duplicates(subset=['identifier'], keep = "first")
  df.set_index('identifier', inplace=True, drop=True)
  store.append(df)
  print(cc, file)
  print(df.shape)
  print(df.columns)
  print(df.info())
  #df.to_csv(file)
  #files.download(file)
# Out:
# 1 trecis2019-B-test.southAfricaFloods2019.csv
# (770, 35)
# Index(['tweet_text', 'user_verified', 'user_followers', 'user_following',
#        'media', 'user_statuses', 'timestamp', 'language', 'location_metadata',
#        'GoodsServices', 'SearchAndRescue', 'InformationWanted', 'Volunteer',
#        'Donations', 'MovePeople', 'FirstPartyObservation',
#        'ThirdPartyObservation', 'Weather', 'EmergingThreats', 'NewSubEvent',
#        'MultimediaShare', 'ServiceAvailable', 'Factoid', 'Official', 'News',
#        'CleanUp', 'Hashtags', 'OriginalEvent', 'ContextualInformation',
#        'Advice', 'Sentiment', 'Discussion', 'Irrelevant', 'Location',
#        'priority_level'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 770 entries, 1121119423153229824 to 1120750978708455424
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_text             770 non-null    object
#  1   user_verified          770 non-null    int64
#  2   user_followers         770 non-null    int64
#  3   user_following         0 non-null      object
#  4   media                  770 non-null    int64
#  5   user_statuses          770 non-null    int64
#  6   timestamp              770 non-null    object
#  7   language               770 non-null    object
#  8   location_metadata      0 non-null      object
#  9   GoodsServices          770 non-null    int64
#  10  SearchAndRescue        770 non-null    int64
#  11  InformationWanted      770 non-null    int64
#  12  Volunteer              770 non-null    int64
#  13  Donations              770 non-null    int64
#  14  MovePeople             770 non-null    int64
#  15  FirstPartyObservation  770 non-null    int64
#  16  ThirdPartyObservation  770 non-null    int64
#  17  Weather                770 non-null    int64
#  18  EmergingThreats        770 non-null    int64
#  19  NewSubEvent            770 non-null    int64
#  20  MultimediaShare        770 non-null    int64
#  21  ServiceAvailable       770 non-null    int64
#  22  Factoid                770 non-null    int64
#  23  Official               770 non-null    int64
#  24  News                   770 non-null    int64
#  25  CleanUp                770 non-null    int64
#  26  Hashtags               770 non-null    int64
#  27  OriginalEvent          770 non-null    int64
#  28  ContextualInformation  770 non-null    int64
#  29  Advice                 770 non-null    int64
#  30  Sentiment              770 non-null    int64
#  31  Discussion             770 non-null    int64
#  32  Irrelevant             770 non-null    int64
#  33  Location               770 non-null    int64
#  34  priority_level         770 non-null    object
# dtypes: int64(29), object(6)
# memory usage: 216.6+ KB
# None
# 2 trecis2019-B-test.sandiegoSynagogueShooting2019.csv
# (598, 35)
# Index(['tweet_text', 'user_verified', 'user_followers', 'user_following',
#        'media', 'user_statuses', 'timestamp', 'language', 'location_metadata',
#        'GoodsServices', 'SearchAndRescue', 'InformationWanted', 'Volunteer',
#        'Donations', 'MovePeople', 'FirstPartyObservation',
#        'ThirdPartyObservation', 'Weather', 'EmergingThreats', 'NewSubEvent',
#        'MultimediaShare', 'ServiceAvailable', 'Factoid', 'Official', 'News',
#        'CleanUp', 'Hashtags', 'OriginalEvent', 'ContextualInformation',
#        'Advice', 'Sentiment', 'Discussion', 'Irrelevant', 'Location',
#        'priority_level'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 598 entries, 1122243202315096064 to 1122250898154184704
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_text             598 non-null    object
#  1   user_verified          598 non-null    int64
#  2   user_followers         598 non-null    int64
#  3   user_following         0 non-null      object
#  4   media                  598 non-null    int64
#  5   user_statuses          598 non-null    int64
#  6   timestamp              598 non-null    object
#  7   language               598 non-null    object
#  8   location_metadata      0 non-null      object
#  9   GoodsServices          598 non-null    int64
#  10  SearchAndRescue        598 non-null    int64
#  11  InformationWanted      598 non-null    int64
#  12  Volunteer              598 non-null    int64
#  13  Donations              598 non-null    int64
#  14  MovePeople             598 non-null    int64
#  15  FirstPartyObservation  598 non-null    int64
#  16  ThirdPartyObservation  598 non-null    int64
#  17  Weather                598 non-null    int64
#  18  EmergingThreats        598 non-null    int64
#  19  NewSubEvent            598 non-null    int64
#  20  MultimediaShare        598 non-null    int64
#  21  ServiceAvailable       598 non-null    int64
#  22  Factoid                598 non-null    int64
#  23  Official               598 non-null    int64
#  24  News                   598 non-null    int64
#  25  CleanUp                598 non-null    int64
#  26  Hashtags               598 non-null    int64
#  27  OriginalEvent          598 non-null    int64
#  28  ContextualInformation  598 non-null    int64
#  29  Advice                 598 non-null    int64
#  30  Sentiment              598 non-null    int64
#  31  Discussion             598 non-null    int64
#  32  Irrelevant             598 non-null    int64
#  33  Location               598 non-null    int64
#  34  priority_level         598 non-null    object
# dtypes: int64(29), object(6)
# memory usage: 168.2+ KB
# None
# 3 trecis2019-B-test.philippinesEarthquake2019.csv
# (1180, 35)
# Index(['tweet_text', 'user_verified', 'user_followers', 'user_following',
#        'media', 'user_statuses', 'timestamp', 'language', 'location_metadata',
#        'GoodsServices', 'SearchAndRescue', 'InformationWanted', 'Volunteer',
#        'Donations', 'MovePeople', 'FirstPartyObservation',
#        'ThirdPartyObservation', 'Weather', 'EmergingThreats', 'NewSubEvent',
#        'MultimediaShare', 'ServiceAvailable', 'Factoid', 'Official', 'News',
#        'CleanUp', 'Hashtags', 'OriginalEvent', 'ContextualInformation',
#        'Advice', 'Sentiment', 'Discussion', 'Irrelevant', 'Location',
#        'priority_level'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 1180 entries, 1121930607242518528 to 1120408853076639744
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_text             1180 non-null   object
#  1   user_verified          1180 non-null   int64
#  2   user_followers         1180 non-null   int64
#  3   user_following         0 non-null      object
#  4   media                  1180 non-null   int64
#  5   user_statuses          1180 non-null   int64
#  6   timestamp              1180 non-null   object
#  7   language               1180 non-null   object
#  8   location_metadata      0 non-null      object
#  9   GoodsServices          1180 non-null   int64
#  10  SearchAndRescue        1180 non-null   int64
#  11  InformationWanted      1180 non-null   int64
#  12  Volunteer              1180 non-null   int64
#  13  Donations              1180 non-null   int64
#  14  MovePeople             1180 non-null   int64
#  15  FirstPartyObservation  1180 non-null   int64
#  16  ThirdPartyObservation  1180 non-null   int64
#  17  Weather                1180 non-null   int64
#  18  EmergingThreats        1180 non-null   int64
#  19  NewSubEvent            1180 non-null   int64
#  20  MultimediaShare        1180 non-null   int64
#  21  ServiceAvailable       1180 non-null   int64
#  22  Factoid                1180 non-null   int64
#  23  Official               1180 non-null   int64
#  24  News                   1180 non-null   int64
#  25  CleanUp                1180 non-null   int64
#  26  Hashtags               1180 non-null   int64
#  27  OriginalEvent          1180 non-null   int64
#  28  ContextualInformation  1180 non-null   int64
#  29  Advice                 1180 non-null   int64
#  30  Sentiment              1180 non-null   int64
#  31  Discussion             1180 non-null   int64
#  32  Irrelevant             1180 non-null   int64
#  33  Location               1180 non-null   int64
#  34  priority_level         1180 non-null   object
# dtypes: int64(29), object(6)
# memory usage: 331.9+ KB
# None
# 4 trecis2019-B-test.cycloneKenneth2019.csv
# (1085, 35)
# Index(['tweet_text', 'user_verified', 'user_followers', 'user_following',
#        'media', 'user_statuses', 'timestamp', 'language', 'location_metadata',
#        'GoodsServices', 'SearchAndRescue', 'InformationWanted', 'Volunteer',
#        'Donations', 'MovePeople', 'FirstPartyObservation',
#        'ThirdPartyObservation', 'Weather', 'EmergingThreats', 'NewSubEvent',
#        'MultimediaShare', 'ServiceAvailable', 'Factoid', 'Official', 'News',
#        'CleanUp', 'Hashtags', 'OriginalEvent', 'ContextualInformation',
#        'Advice', 'Sentiment', 'Discussion', 'Irrelevant', 'Location',
#        'priority_level'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 1085 entries, 1122818630436020224 to 1122043118096928768
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_text             1085 non-null   object
#  1   user_verified          1085 non-null   int64
#  2   user_followers         1085 non-null   int64
#  3   user_following         0 non-null      object
#  4   media                  1085 non-null   int64
#  5   user_statuses          1085 non-null   int64
#  6   timestamp              1085 non-null   object
#  7   language               1085 non-null   object
#  8   location_metadata      0 non-null      object
#  9   GoodsServices          1085 non-null   int64
#  10  SearchAndRescue        1085 non-null   int64
#  11  InformationWanted      1085 non-null   int64
#  12  Volunteer              1085 non-null   int64
#  13  Donations              1085 non-null   int64
#  14  MovePeople             1085 non-null   int64
#  15  FirstPartyObservation  1085 non-null   int64
#  16  ThirdPartyObservation  1085 non-null   int64
#  17  Weather                1085 non-null   int64
#  18  EmergingThreats        1085 non-null   int64
#  19  NewSubEvent            1085 non-null   int64
#  20  MultimediaShare        1085 non-null   int64
#  21  ServiceAvailable       1085 non-null   int64
#  22  Factoid                1085 non-null   int64
#  23  Official               1085 non-null   int64
#  24  News                   1085 non-null   int64
#  25  CleanUp                1085 non-null   int64
#  26  Hashtags               1085 non-null   int64
#  27  OriginalEvent          1085 non-null   int64
#  28  ContextualInformation  1085 non-null   int64
#  29  Advice                 1085 non-null   int64
#  30  Sentiment              1085 non-null   int64
#  31  Discussion             1085 non-null   int64
#  32  Irrelevant             1085 non-null   int64
#  33  Location               1085 non-null   int64
#  34  priority_level         1085 non-null   object
# dtypes: int64(29), object(6)
# memory usage: 305.2+ KB
# None
# 5 trecis2019-B-test.coloradoStemShooting2019.csv
# (910, 35)
# Index(['tweet_text', 'user_verified', 'user_followers', 'user_following',
#        'media', 'user_statuses', 'timestamp', 'language', 'location_metadata',
#        'GoodsServices', 'SearchAndRescue', 'InformationWanted', 'Volunteer',
#        'Donations', 'MovePeople', 'FirstPartyObservation',
#        'ThirdPartyObservation', 'Weather', 'EmergingThreats', 'NewSubEvent',
#        'MultimediaShare', 'ServiceAvailable', 'Factoid', 'Official', 'News',
#        'CleanUp', 'Hashtags', 'OriginalEvent', 'ContextualInformation',
#        'Advice', 'Sentiment', 'Discussion', 'Irrelevant', 'Location',
#        'priority_level'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 910 entries, 1125953449609265152 to 1125868753114357760
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_text             910 non-null    object
#  1   user_verified          910 non-null    int64
#  2   user_followers         910 non-null    int64
#  3   user_following         0 non-null      object
#  4   media                  910 non-null    int64
#  5   user_statuses          910 non-null    int64
#  6   timestamp              910 non-null    object
#  7   language               910 non-null    object
#  8   location_metadata      0 non-null      object
#  9   GoodsServices          910 non-null    int64
#  10  SearchAndRescue        910 non-null    int64
#  11  InformationWanted      910 non-null    int64
#  12  Volunteer              910 non-null    int64
#  13  Donations              910 non-null    int64
#  14  MovePeople             910 non-null    int64
#  15  FirstPartyObservation  910 non-null    int64
#  16  ThirdPartyObservation  910 non-null    int64
#  17  Weather                910 non-null    int64
#  18  EmergingThreats        910 non-null    int64
#  19  NewSubEvent            910 non-null    int64
#  20  MultimediaShare        910 non-null    int64
#  21  ServiceAvailable       910 non-null    int64
#  22  Factoid                910 non-null    int64
#  23  Official               910 non-null    int64
#  24  News                   910 non-null    int64
#  25  CleanUp                910 non-null    int64
#  26  Hashtags               910 non-null    int64
#  27  OriginalEvent          910 non-null    int64
#  28  ContextualInformation  910 non-null    int64
#  29  Advice                 910 non-null    int64
#  30  Sentiment              910 non-null    int64
#  31  Discussion             910 non-null    int64
#  32  Irrelevant             910 non-null    int64
#  33  Location               910 non-null    int64
#  34  priority_level         910 non-null    object
# dtypes: int64(29), object(6)
# memory usage: 255.9+ KB
# None
# 6 trecis2019-B-test.albertaWildfires2019.csv
# (1210, 35)
# Index(['tweet_text', 'user_verified', 'user_followers', 'user_following',
#        'media', 'user_statuses', 'timestamp', 'language', 'location_metadata',
#        'GoodsServices', 'SearchAndRescue', 'InformationWanted', 'Volunteer',
#        'Donations', 'MovePeople', 'FirstPartyObservation',
#        'ThirdPartyObservation', 'Weather', 'EmergingThreats', 'NewSubEvent',
#        'MultimediaShare', 'ServiceAvailable', 'Factoid', 'Official', 'News',
#        'CleanUp', 'Hashtags', 'OriginalEvent', 'ContextualInformation',
#        'Advice', 'Sentiment', 'Discussion', 'Irrelevant', 'Location',
#        'priority_level'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 1210 entries, 1134239576111771648 to 1133019628014329856
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_text             1210 non-null   object
#  1   user_verified          1210 non-null   int64
#  2   user_followers         1210 non-null   int64
#  3   user_following         0 non-null      object
#  4   media                  1210 non-null   int64
#  5   user_statuses          1210 non-null   int64
#  6   timestamp              1210 non-null   object
#  7   language               1210 non-null   object
#  8   location_metadata      0 non-null      object
#  9   GoodsServices          1210 non-null   int64
#  10  SearchAndRescue        1210 non-null   int64
#  11  InformationWanted      1210 non-null   int64
#  12  Volunteer              1210 non-null   int64
#  13  Donations              1210 non-null   int64
#  14  MovePeople             1210 non-null   int64
#  15  FirstPartyObservation  1210 non-null   int64
#  16  ThirdPartyObservation  1210 non-null   int64
#  17  Weather                1210 non-null   int64
#  18  EmergingThreats        1210 non-null   int64
#  19  NewSubEvent            1210 non-null   int64
#  20  MultimediaShare        1210 non-null   int64
#  21  ServiceAvailable       1210 non-null   int64
#  22  Factoid                1210 non-null   int64
#  23  Official               1210 non-null   int64
#  24  News                   1210 non-null   int64
#  25  CleanUp                1210 non-null   int64
#  26  Hashtags               1210 non-null   int64
#  27  OriginalEvent          1210 non-null   int64
#  28  ContextualInformation  1210 non-null   int64
#  29  Advice                 1210 non-null   int64
#  30  Sentiment              1210 non-null   int64
#  31  Discussion             1210 non-null   int64
#  32  Irrelevant             1210 non-null   int64
#  33  Location               1210 non-null   int64
#  34  priority_level         1210 non-null   object
# dtypes: int64(29), object(6)
# memory usage: 340.3+ KB
# None

# %%
print(len(store))
for i in range(len(file_names)):
  yoman = "__" + file_names[i]
  print(i, yoman)
  store[i].to_csv(yoman)
  files.download(yoman)
# Out:
# 6
# 0 __trecis2019-B-test.southAfricaFloods2019.csv
# 1 __trecis2019-B-test.sandiegoSynagogueShooting2019.csv
# 2 __trecis2019-B-test.philippinesEarthquake2019.csv
# 3 __trecis2019-B-test.cycloneKenneth2019.csv
# 4 __trecis2019-B-test.coloradoStemShooting2019.csv
# 5 __trecis2019-B-test.albertaWildfires2019.csv
