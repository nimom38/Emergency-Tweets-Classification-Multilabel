# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ff6e75e3-4003-49ff-8c0d-776c6b217092" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ff6e75e3-4003-49ff-8c0d-776c6b217092">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving trecis2020-B.stormDennis2020.csv to trecis2020-B.stormDennis2020.csv
# Saving trecis2020-B.beirutExplosion2020.csv to trecis2020-B.beirutExplosion2020.csv
# Saving trecis2020-B.tennesseeTornadoOutbreak2020.csv to trecis2020-B.tennesseeTornadoOutbreak2020.csv
# Saving trecis2020-B.tropicalStormCristobal2020.csv to trecis2020-B.tropicalStormCristobal2020.csv
# Saving trecis2020-B.edenvilleDamFailure2020.csv to trecis2020-B.edenvilleDamFailure2020.csv
# Saving trecis2020-B.stormJorge2020.csv to trecis2020-B.stormJorge2020.csv
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
from google.colab import files
#uploaded = files.upload()

# %%
import pandas as pd

# %%
clss = [
        "GoodsServices",
"SearchAndRescue",
"InformationWanted",
"Volunteer",
"Donations",
"MovePeople",
"FirstPartyObservation",
"ThirdPartyObservation",
"Weather",
"EmergingThreats",
"NewSubEvent",
"MultimediaShare",
"ServiceAvailable",
"Factoid",
"Official",
"News",
"CleanUp",
"Hashtags",
"OriginalEvent",
"ContextualInformation",
"Advice",
"Sentiment",
"Discussion",
"Irrelevant",
"Location"
]

# %%
def func(a, b):
  for index, value in a.items():
    huhu = value
    if str(int(huhu)) == str(int(b)):
     # print(huhu, b)
      return True
  return False

# %%
def func2(a, b):
  for index, value in a.items():
    huhu = value
    if str(int(huhu)) == str(int(b)):
      return index

# %%
def check(a):
  a = str(a)
  for ch in a:
    if ch >= '0' and ch <= '9':
      continue
    if ch == '.':
      continue
    return False
  return True

# %%
import json
import math
import numpy
cc = 0
combo = pd.read_csv('/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/Combined labels.csv')
print(combo.columns)
hoho = combo['postID']
store = []
file_names = [
              '/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/6.-TestSet_2020_B/trecis2020-B.beirutExplosion2020.csv',
              '/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/6.-TestSet_2020_B/trecis2020-B.edenvilleDamFailure2020.csv',
              '/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/6.-TestSet_2020_B/trecis2020-B.houstonExplosion2020.csv',
              '/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/6.-TestSet_2020_B/trecis2020-B.portervilleLibraryFire2020.csv',
              '/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/6.-TestSet_2020_B/trecis2020-B.sanFranciscoPierFire2020.csv',
              '/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/6.-TestSet_2020_B/trecis2020-B.southeastTornadoOutbreak2020.csv',
              '/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/6.-TestSet_2020_B/trecis2020-B.stormCiara2020.csv',
              '/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/6.-TestSet_2020_B/trecis2020-B.stormDennis2020.csv',
              '/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/6.-TestSet_2020_B/trecis2020-B.stormJorge2020.csv',
              '/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/6.-TestSet_2020_B/trecis2020-B.tennesseeDerecho2020.csv',
              '/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/6.-TestSet_2020_B/trecis2020-B.tennesseeTornadoOutbreak2020.csv',
              '/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/6.-TestSet_2020_B/trecis2020-B.texasAMCommerceShooting2020.csv',
              '/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/6.-TestSet_2020_B/trecis2020-B.tropicalStormCristobal2020.csv',
              '/content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/6.-TestSet_2020_B/trecis2020-B.virraMallHostageSituation2020.csv'
]
assert len(file_names) == 14
# Out:
# Index(['postID', 'eventID', 'eventName', 'eventDescription', 'eventType',
#        'postCategories', 'postPriority'],
#       dtype='object')

# %%
for file in file_names:
  df = pd.read_csv(file)
  for row in df.itertuples(name=None):
    print(row)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
store.clear()
cc = 0
for file in file_names:
  cc += 1
  df = pd.read_csv(file)
  arr = []
  for row in df.itertuples(name=None):
    if (row[6] is None) or ((not isinstance(row[6], str)) and (math.isnan(row[6]) == True)):
      continue
    if (row[6] == "TWEETS"):
      continue
    if check(row[6]) == False:
      continue
#    if func(hoho, row[6]) == False:
#      continue
#    yap = func2(hoho, row[6])
    xxx = None
    if (row[2] is not None) and (isinstance(row[2], str)):
      xxx = eval(row[2])
    dic = {}
    dic['tweet_text'] = None
    if xxx is not None:
      assert 'full_text' in xxx
      dic['tweet_text'] = xxx['full_text']
    dic['user_verified'] = None
    if xxx is not None:
      if 'user.verified' in xxx:
        dic['user_verified'] = int(xxx['user.verified']=='true')
    dic['user_followers'] = None
    if xxx is not None:
      if 'user.followersCount' in xxx:
        dic['user_followers'] = int(xxx['user.followersCount'])
      if 'user.followers_count' in xxx:
        dic['user_followers'] = int(xxx['user.followers_count'])
    dic['user_following'] = None
    dic['media'] = 0
    if xxx is not None:
      if 'mediaEntities' in xxx:
        print( -1111, type(xxx['mediaEntities']), xxx['mediaEntities'] )
        dic['media'] = int(len(xxx['mediaEntities'])>2)
      if 'entities.media' in xxx:
        print( -2222, type(xxx['entities.media']), xxx['entities.media'] )
        dic['media'] = int(len(xxx['entities.media'])>2)
      if 'retweeted_status.extended_entities.media' in xxx:
        print( -3333, type(xxx['retweeted_status.extended_entities.media']), xxx['retweeted_status.extended_entities.media'] )
        dic['media'] = int(len(xxx['retweeted_status.extended_entities.media'])>2)
    dic['user_statuses'] = None
    if xxx is not None:
      if 'user.statusesCount' in xxx:
        dic['user_statuses'] = int(xxx['user.statusesCount'])
      if 'user.statuses_count' in xxx:
        dic['user_statuses'] = int(xxx['user.statuses_count'])
    dic['timestamp'] = None
    if xxx is not None:
      if 'timestamp' in xxx:
        dic['timestamp'] = xxx['timestamp']
    dic['identifier'] = str(row[6])
    dic['language'] = None
    if xxx is not None:
      if 'user.lang' in xxx:
        dic['language'] = xxx['user.lang']
    dic['location_metadata'] = None
    if xxx is not None:
      if 'place.boundingBoxCoordinates' in xxx:
        dic['location_metadata'] = xxx['place.boundingBoxCoordinates']
    for words in clss:
      dic[words] = 0
    dic['priority_level'] = "FIND OUT"
#    hmm = int(row[6])
#    temp = []
#    temp = combo.iloc[yap, 5]
#    temp2 = ""
#    for i in range(len(temp)):
#      if (temp[i] == '[') or (temp[i] == ']') or (temp[i] == ',') or (temp[i] == '\''):
#        temp2 += ' '
#      else:
#        temp2 += temp[i]
#    temp2 = list(temp2.split())
#    for words in temp2:
#      dic[words] = 1
#    dic['priority_level'] = combo.iloc[yap, 6]
    arr.append(dic)
  df = pd.DataFrame.from_dict(arr)
  df.drop_duplicates(subset=['identifier'], keep = "first")
  df.set_index('identifier', inplace=True, drop=True)
  store.append(df)
  print(cc, file)
  print(df.shape)
  print(df.columns)
  print(df.info())
  #df.to_csv(file)
  #files.download(file)

# %%
print(len(store))
for i in range(len(file_names)):
  yoman = file_names[i] + "______"
  print(i, yoman)
  store[i].to_csv(yoman)
  files.download(yoman)
# Out:
# 14
# 0 /content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/6.-TestSet_2020_B/trecis2020-B.beirutExplosion2020.csv______
# 1 /content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/6.-TestSet_2020_B/trecis2020-B.edenvilleDamFailure2020.csv______
# 2 /content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/6.-TestSet_2020_B/trecis2020-B.houstonExplosion2020.csv______
# 3 /content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/6.-TestSet_2020_B/trecis2020-B.portervilleLibraryFire2020.csv______
# 4 /content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/6.-TestSet_2020_B/trecis2020-B.sanFranciscoPierFire2020.csv______
# 5 /content/drive/MyDrive/Colab-Notebooks/preprocess/actual-kaj-starts-now!/Datasets/6.-TestSet_2020_B/trecis2020-B.southeastTornadoOutbreak2020.csv______
# ...
