# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-59459c98-bacb-47f2-8d7a-2cf1c577a151" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-59459c98-bacb-47f2-8d7a-2cf1c577a151">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving nepalEarthquake2015.json to nepalEarthquake2015.json

# %%
import pandas as pd
import json

# %%
file_name = "nepalEarthquake2015.json"

dat=list()
with open (file_name, 'r') as f:
    for l in f.readlines():
        if not l.strip (): # skip empty lines
            continue

        json_data = json.loads (l)
        dat.append(json_data)

dat
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
tweet_data_frame = pd.DataFrame.from_dict(dat)
tweet_data_frame.set_index('identifier')
# Out:
#                                                                  text  ...                                              media
# identifier                                                             ...
# 591907253239820288  I feel so bad for the people of Nepal. #PrayFo...  ...                                                 []
# 591909766785605632  @keswickjane Hi it's Amy from The Bay here - C...  ...                                                 []
# 591908028993114113  Treat with extreme caution but this is the USG...  ...  [{'identifier': '591908028057804800', 'url': '...
# 591906719099420672  Earthquake near/in Kathmandu - not clear what ...  ...                                                 []
# 591909837744701440  These Pics tell pain of Nepal Earthquake &gt; ...  ...                                                 []
# ...                                                               ...  ...                                                ...
# 593265516145410048  Much as I grieve for Nepal I cannot understand...  ...                                                 []
# 593265107787972608  I know I haven't been tweeting about #Baltimor...  ...                                                 []
# 593265049474445312  Humane slaughter methods followed https://t.co...  ...                                                 []
# 593264050403835904  I hope they don't misuse all the money that's ...  ...                                                 []
# 593262545181417472  I think #Presstitutes @IndianExpress @anantgoe...  ...                                                 []
#
# [7289 rows x 9 columns]

# %%
from google.colab import files
tweet_data_frame.to_csv('nepalEarthquake2015.csv')
