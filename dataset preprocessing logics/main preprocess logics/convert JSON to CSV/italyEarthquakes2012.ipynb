# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ab068a99-7a0b-4624-82cc-354249bb0dba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ab068a99-7a0b-4624-82cc-354249bb0dba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving italyEarthquakes2012.json to italyEarthquakes2012.json

# %%
import pandas as pd
import json

# %%
file_name = "italyEarthquakes2012.json"

dat=list()
with open (file_name, 'r') as f:
    for l in f.readlines():
        if not l.strip (): # skip empty lines
            continue

        json_data = json.loads (l)
        dat.append(json_data)

dat
# Out:
# [{'identifier': '204093670847291392',
#   'lang': 'en',
#   'location': None,
#   'media': [],
#   'metadata': {'content': 'RT @AP: Reports: 3 dead in magnitude-5.9 earthquake that strikes near Bologna, Italy: http://t.co/oMng91FE -JM',
#    'contributors': 'null',
#    'coordinates': 'null',
#    'created_at': 'Sun May 20 06:18:17 +0000 2012',
#    'docno': '204093670847291392',
#    'entities.hashtags': '[]',
#    'entities.symbols': '[]',
#    'entities.urls': '[{"expanded_url":"http://apne.ws/Lpl6Dp","indices":[86,106],"display_url":"apne.ws/Lpl6Dp","url":"http://t.co/oMng91FE"}]',
#    'entities.user_mentions': '[{"id":51241574,"name":"The Associated Press","indices":[3,6],"screen_name":"AP","id_str":"51241574"}]',
#    'favorite_count': '0',
#    'favorited': 'false',
#    'geo': 'null',
#    'id': '204093670847291392',
#    'id_str': '204093670847291392',
#    'in_reply_to_screen_name': 'null',
#    'in_reply_to_status_id': 'null',
#    'in_reply_to_status_id_str': 'null',
# ...

# %%
tweet_data_frame = pd.DataFrame.from_dict(dat)
tweet_data_frame.set_index('identifier')
# Out:
#                                                                  text  ... media
# identifier                                                             ...
# 204093670847291392  RT @AP: Reports: 3 dead in magnitude-5.9 earth...  ...    []
# 204099568009355265  RT @cnni: Quake hits northern Italy, one dead ...  ...    []
# 204101208015769600  Three killed in Italy earthquake: An earthquak...  ...    []
# 204101451268624385  RT @CNN: At least 3 dead after earthquake rock...  ...    []
# 204105960145428480  RT @BBCWorld: Three killed in Italy earthquake...  ...    []
# ...                                                               ...  ...   ...
# 204046325518577664  5.9-magnitude earthquake strikes near Bologna,...  ...    []
# 204049387389857792  RT @mpoppel: 5.1-magnitude aftershock hits nor...  ...    []
# 204083688382799872  #InstantFollowBack Quake hits northern Italy, ...  ...    []
# 204085705847226368  RT @nytimes: Strong Quake Hits North Italy, at...  ...    []
# ...

# %%
from google.colab import files
tweet_data_frame.to_csv('italyEarthquakes2012.csv')
