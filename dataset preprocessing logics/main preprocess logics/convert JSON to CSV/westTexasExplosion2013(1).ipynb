# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5376e7f8-fdcb-4c75-87ad-279057511406" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5376e7f8-fdcb-4c75-87ad-279057511406">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving westTexasExplosion2013.json to westTexasExplosion2013.json

# %%
import pandas as pd
import json

# %%
file_name = "westTexasExplosion2013.json"

dat=list()
with open (file_name, 'r') as f:
    for l in f.readlines():
        if not l.strip (): # skip empty lines
            continue

        json_data = json.loads (l)
        dat.append(json_data)

dat
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
tweet_data_frame = pd.DataFrame.from_dict(dat)
tweet_data_frame.set_index('identifier')
# Out:
#                                                                  text  ... media
# identifier                                                             ...
# 324681353662709760  @MontesCb7 Waco, Texas!! I use to live near th...  ...    []
# 324693550694543361  Really? Another explosion, now in Texas? What ...  ...    []
# 324694339240460289  Explosion reported at fertilizer plant in West...  ...    []
# 324694565753851904  RT @Donna4843: triage for injured at Reagan st...  ...    []
# 324694993551884288  RT @911BUFF: TEXAS: MASSIVE EXPLOSION U/D - LO...  ...    []
# ...                                                               ...  ...   ...
# 333246042751516673  RT @GlobalGrindNews: Criminal investigation la...  ...    []
# 333283078464221185  RT @rcooley123: First Responder to Fertilizer ...  ...    []
# 334273596891492352  Former West Medic Denies Involvement in Deadly...  ...    []
# 334370934104399872  Bulldozers begin demolishing structures damage...  ...    []
# 334520955965693953  "how many fertilizer plants are there in texas...  ...    []
#
# [630 rows x 9 columns]

# %%
from google.colab import files
tweet_data_frame.to_csv('westTexasExplosion2013.csv')
