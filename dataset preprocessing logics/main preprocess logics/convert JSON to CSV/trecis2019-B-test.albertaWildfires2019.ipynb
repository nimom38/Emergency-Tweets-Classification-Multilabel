# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-75abffc9-7aad-47c6-88ba-36127ef80f01" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-75abffc9-7aad-47c6-88ba-36127ef80f01">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving trecis2019-B-test.albertaWildfires2019.json.gz to trecis2019-B-test.albertaWildfires2019.json.gz

# %%
# !gunzip "trecis2019-B-test.albertaWildfires2019.json.gz"

# %%
import pandas as pd
import json

# %%
file_name = "trecis2019-B-test.albertaWildfires2019.json"

dat=list()
with open (file_name, 'r') as f:
    for l in f.readlines():
        if not l.strip (): # skip empty lines
            continue

        json_data = json.loads (l)
        dat.append(json_data)

dat
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
for i in range(len(dat)):
  dat[i]['identifier'] = dat[i]['allProperties']['id']
tweet_data_frame = pd.DataFrame.from_dict(dat)
tweet_data_frame.set_index('identifier')
# Out:
#                                                          allProperties  ...                 topic
# identifier                                                              ...
# 1134239576111771648  {'user.listed_count': '59', 'user.verified': '...  ...  albertaWildfires2019
# 1131161667398774784  {'user.listed_count': '5', 'user.verified': 'f...  ...  albertaWildfires2019
# 1134148540719017984  {'user.listed_count': '1', 'user.verified': 'f...  ...  albertaWildfires2019
# 1133705772246786049  {'user.listed_count': '0', 'user.verified': 'f...  ...  albertaWildfires2019
# 1134018172309295104  {'user.listed_count': '30', 'user.verified': '...  ...  albertaWildfires2019
# ...                                                                ...  ...                   ...
# 1134587894507532288  {'user.listed_count': '20', 'user.profile_back...  ...  albertaWildfires2019
# 1133592232785731584  {'user.listed_count': '304', 'user.verified': ...  ...  albertaWildfires2019
# ...

# %%
from google.colab import files
tweet_data_frame.to_csv('trecis2019-B-test.albertaWildfires2019.csv')
