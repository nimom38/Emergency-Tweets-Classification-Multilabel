# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b3f2ae1c-1ae0-44d3-a5b3-89048962faa3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b3f2ae1c-1ae0-44d3-a5b3-89048962faa3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving chileEarthquake2014.json to chileEarthquake2014.json

# %%
import pandas as pd
import json

# %%
file_name = "chileEarthquake2014.json"

dat=list()
with open (file_name, 'r') as f:
    for l in f.readlines():
        if not l.strip (): # skip empty lines
            continue

        json_data = json.loads (l)
        dat.append(json_data)

dat
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
tweet_data_frame = pd.DataFrame.from_dict(dat)
tweet_data_frame.set_index('identifier')
# Out:
#                                                                  text  ...                                              media
# identifier                                                             ...
# 451308164932440064  #ChileEarthquake Update: Chilean Interior Mini...  ...                                                 []
# 451293013763817472  Powerful earthquake strikes off the coast of C...  ...                                                 []
# 451285666350239744                     #PrayForChile God is with you.  ...                                                 []
# 451300464269983744  Five dead after 8.2 magnitude earthquake off c...  ...                                                 []
# 451296996490346496  unbelievable img "@Larryferlazzo RT @stevesilb...  ...  [{'identifier': '451165543685300225', 'url': '...
# ...                                                               ...  ...                                                ...
# 452277201896235008  Felt #earthquake M5.4 strikes 109 km NW of #Sa...  ...                                                 []
# 452272028746121216  Chile earthquake: How loss of life, damage was...  ...                                                 []
# 452278592114655234  Powerful Earthquake Hits Off Chile, Triggers T...  ...                                                 []
# 452668167047745536  Prayers to those in chile who were effected fr...  ...                                                 []
# 456369685957582848  Powerful earthquake strikes off Chile, trigger...  ...                                                 []
#
# [311 rows x 9 columns]

# %%
from google.colab import files
tweet_data_frame.to_csv('chileEarthquake2014.csv')
