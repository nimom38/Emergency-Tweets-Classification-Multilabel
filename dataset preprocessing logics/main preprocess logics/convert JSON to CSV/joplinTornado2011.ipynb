# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2a757aee-2f76-4f34-91d0-88a7b7d037b0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a757aee-2f76-4f34-91d0-88a7b7d037b0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving joplinTornado2011.json to joplinTornado2011.json

# %%
import pandas as pd
import json

# %%
file_name = "joplinTornado2011.json"

dat=list()
with open (file_name, 'r') as f:
    for l in f.readlines():
        if not l.strip (): # skip empty lines
            continue

        json_data = json.loads (l)
        dat.append(json_data)

dat
# Out:
# [{'identifier': '74290454534963200',
#   'lang': 'en',
#   'location': None,
#   'media': [],
#   'metadata': {'content': '#PrayN4t/Lords  Healing & Restoration N Joplin. Church Destroyed By Tornado, Yet t/RoofTop Cross Still Standing, Refruge N #Jesus #Christ',
#    'contributors': 'null',
#    'coordinates': 'null',
#    'created_at': 'Sat May 28 01:46:39 +0000 2011',
#    'docno': '74290454534963200',
#    'entities.hashtags': '[{"text":"PrayN4t","indices":[0,8]},{"text":"Jesus","indices":[123,129]},{"text":"Christ","indices":[130,137]}]',
#    'entities.symbols': '[]',
#    'entities.urls': '[]',
#    'entities.user_mentions': '[]',
#    'favorite_count': '0',
#    'favorited': 'false',
#    'geo': 'null',
#    'id': '74290454534963200',
#    'id_str': '74290454534963200',
#    'in_reply_to_screen_name': 'null',
#    'in_reply_to_status_id': 'null',
#    'in_reply_to_status_id_str': 'null',
#    'in_reply_to_user_id': 'null',
#    'in_reply_to_user_id_str': 'null',
#    'is_quote_status': 'false',
#    'label': '???',
#    'lang': 'en',
#    'place': 'null',
#    'retweet_count': '3',
#    'retweeted': 'false',
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'srcjson': '{"contributors":null,"text":"#PrayN4t/Lords  Healing & Restoration N Joplin. Church Destroyed By Tornado, Yet t/RoofTop Cross Still Standing, Refruge N #Jesus #Christ","geo":null,"retweeted":false,"in_reply_to_screen_name":null,"truncated":false,"lang":"en","entities":{"symbols":[],"urls":[],"hashtags":[{"text":"PrayN4t","indices":[0,8]},{"text":"Jesus","indices":[123,129]},{"text":"Christ","indices":[130,137]}],"user_mentions":[]},"in_reply_to_status_id_str":null,"is_quote_status":false,"id":74290454534963200,"source":"<a href=\\"https://about.twitter.com/products/tweetdeck\\" rel=\\"nofollow\\">TweetDeck<\\/a>","in_reply_to_user_id_str":null,"favorited":false,"in_reply_to_status_id":null,"retweet_count":3,"created_at":"Sat May 28 01:46:39 +0000 2011","in_reply_to_user_id":null,"favorite_count":0,"id_str":"74290454534963200","place":null,"user":{"location":"This Side of Heaven","default_profile":false,"profile_background_tile":false,"statuses_count":16994,"lang":"en","profile_link_color":"2FC2EF","id":92890115,"following":false,"protected":false,"favourites_count":5655,"profile_text_color":"666666","description":"Let your Light so Shine before men, that they may see your Good works and Glorify your Father in Heaven. Walk in t/LIGHT Slow & Steady towards Christ & Heaven!","verified":false,"contributors_enabled":false,"profile_sidebar_border_color":"181A1E","name":"A_Child of God2","profile_background_color":"1A1B1F","created_at":"Fri Nov 27 03:04:27 +0000 2009","is_translation_enabled":false,"default_profile_image":false,"followers_count":6054,"has_extended_profile":false,"profile_image_url_https":"https://pbs.twimg.com/profile_images/547999544483385344/Jb-BYUeA_normal.jpeg","geo_enabled":false,"profile_background_image_url":"http://abs.twimg.com/images/themes/theme9/bg.gif","profile_background_image_url_https":"https://abs.twimg.com/images/themes/theme9/bg.gif","follow_request_sent":false,"entities":{"description":{"urls":[]}},"url":null,"utc_offset":null,"time_zone":null,"translator_type":"none","notifications":false,"profile_use_background_image":true,"friends_count":2865,"profile_sidebar_fill_color":"252429","screen_name":"Gods_Lighthouse","id_str":"92890115","profile_image_url":"http://pbs.twimg.com/profile_images/547999544483385344/Jb-BYUeA_normal.jpeg","listed_count":258,"is_translator":false},"coordinates":null}',
#    'text': '#PrayN4t/Lords  Healing & Restoration N Joplin. Church Destroyed By Tornado, Yet t/RoofTop Cross Still Standing, Refruge N #Jesus #Christ',
#    'timestamp': '1306543599361',
#    'truncated': 'false',
#    'user.contributors_enabled': 'false',
#    'user.created_at': 'Fri Nov 27 03:04:27 +0000 2009',
#    'user.default_profile': 'false',
#    'user.default_profile_image': 'false',
#    'user.description': 'Let your Light so Shine before men, that they may see your Good works and Glorify your Father in Heaven. Walk in t/LIGHT Slow & Steady towards Christ & Heaven!',
#    'user.entities.description.urls': '[]',
#    'user.favourites_count': '5655',
#    'user.follow_request_sent': 'false',
#    'user.followers_count': '6054',
#    'user.following': 'false',
#    'user.friends_count': '2865',
#    'user.geo_enabled': 'false',
#    'user.has_extended_profile': 'false',
#    'user.id': '92890115',
#    'user.id_str': '92890115',
#    'user.is_translation_enabled': 'false',
#    'user.is_translator': 'false',
#    'user.lang': 'en',
#    'user.listed_count': '258',
#    'user.location': 'This Side of Heaven',
#    'user.name': 'A_Child of God2',
#    'user.notifications': 'false',
#    'user.profile_background_color': '1A1B1F',
#    'user.profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    'user.profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    'user.profile_background_tile': 'false',
#    'user.profile_image_url': 'http://pbs.twimg.com/profile_images/547999544483385344/Jb-BYUeA_normal.jpeg',
#    'user.profile_image_url_https': 'https://pbs.twimg.com/profile_images/547999544483385344/Jb-BYUeA_normal.jpeg',
#    'user.profile_link_color': '2FC2EF',
#    'user.profile_sidebar_border_color': '181A1E',
#    'user.profile_sidebar_fill_color': '252429',
#    'user.profile_text_color': '666666',
#    'user.profile_use_background_image': 'true',
#    'user.protected': 'false',
#    'user.screen_name': 'Gods_Lighthouse',
#    'user.statuses_count': '16994',
#    'user.time_zone': 'null',
#    'user.translator_type': 'none',
#    'user.url': 'null',
#    'user.utc_offset': 'null',
#    'user.verified': 'false'},
#   'score': 0.0,
#   'statisicalData': {'User Followers': 6054.0,
#    'User Follows': 2865.0,
#    'User Statuses': 16994.0},
#   'text': '#PrayN4t/Lords  Healing & Restoration N Joplin. Church Destroyed By Tornado, Yet t/RoofTop Cross Still Standing, Refruge N #Jesus #Christ',
#   'timestamp': 1306543599361,
#   'type': 'TWEETS'},
#  {'identifier': '74920217951744000',
#   'lang': 'en',
#   'location': {'description': None,
#    'geolocation': {'latitude': 41.515476, 'longitude': -72.75753},
#    'identifier': None,
#    'name': 'Connecticut (United States)',
#    'radius': 0.0},
#   'media': [],
#   'metadata': {'content': 'RT @Bill_Gross: Amazing - and stunningly sad - pictures of before and after the #Tornado swept through #Joplin: http://j.mp/lfa80S from  ...',
#    'contributors': 'null',
#    'coordinates': 'null',
#    'created_at': 'Sun May 29 19:29:06 +0000 2011',
#    'docno': '74920217951744000',
#    'entities.hashtags': '[{"text":"Tornado","indices":[80,88]},{"text":"Joplin","indices":[103,110]}]',
#    'entities.symbols': '[]',
#    'entities.urls': '[]',
#    'entities.user_mentions': '[{"id":47539748,"name":"Bill Gross","indices":[3,14],"screen_name":"Bill_Gross","id_str":"47539748"}]',
#    'favorite_count': '0',
#    'favorited': 'false',
#    'geo': 'null',
#    'id': '74920217951744000',
#    'id_str': '74920217951744000',
#    'in_reply_to_screen_name': 'null',
#    'in_reply_to_status_id': 'null',
#    'in_reply_to_status_id_str': 'null',
#    'in_reply_to_user_id': 'null',
#    'in_reply_to_user_id_str': 'null',
#    'is_quote_status': 'false',
#    'label': '???',
#    'lang': 'en',
#    'place': 'null',
#    'retweet_count': '70',
#    'retweeted': 'false',
#    'retweeted_status.contributors': 'null',
#    'retweeted_status.coordinates': 'null',
#    'retweeted_status.created_at': 'Sun May 29 00:27:20 +0000 2011',
#    'retweeted_status.entities.hashtags': '[{"text":"Tornado","indices":[64,72]},{"text":"Joplin","indices":[87,94]},{"text":"Google","indices":[120,127]}]',
#    'retweeted_status.entities.symbols': '[]',
#    'retweeted_status.entities.urls': '[]',
#    'retweeted_status.entities.user_mentions': '[]',
#    'retweeted_status.favorite_count': '31',
#    'retweeted_status.favorited': 'false',
#    'retweeted_status.geo': 'null',
#    'retweeted_status.id': '74632883578482688',
#    'retweeted_status.id_str': '74632883578482688',
#    'retweeted_status.in_reply_to_screen_name': 'null',
#    'retweeted_status.in_reply_to_status_id': 'null',
#    'retweeted_status.in_reply_to_status_id_str': 'null',
#    'retweeted_status.in_reply_to_user_id': 'null',
#    'retweeted_status.in_reply_to_user_id_str': 'null',
#    'retweeted_status.is_quote_status': 'false',
#    'retweeted_status.lang': 'en',
#    'retweeted_status.place': 'null',
#    'retweeted_status.retweet_count': '70',
#    'retweeted_status.retweeted': 'false',
#    'retweeted_status.source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'retweeted_status.text': 'Amazing - and stunningly sad - pictures of before and after the #Tornado swept through #Joplin: http://j.mp/lfa80S from #Google street view.',
#    'retweeted_status.truncated': 'false',
#    'retweeted_status.user.contributors_enabled': 'false',
#    'retweeted_status.user.created_at': 'Tue Jun 16 04:14:54 +0000 2009',
#    'retweeted_status.user.default_profile': 'false',
#    'retweeted_status.user.default_profile_image': 'false',
#    'retweeted_status.user.description': 'Founder of Technology Incubator Idealab and 100 companies in last 30 years. Tweeting while on my quest for learning in life and at conferences.',
#    'retweeted_status.user.entities.description.urls': '[]',
#    'retweeted_status.user.entities.url.urls': '[{"expanded_url":"http://www.BillGross.com","indices":[0,22],"display_url":"BillGross.com","url":"http://t.co/6lC0EBEbL6"}]',
#    'retweeted_status.user.favourites_count': '5299',
#    'retweeted_status.user.follow_request_sent': 'false',
#    'retweeted_status.user.followers_count': '247367',
#    'retweeted_status.user.following': 'false',
#    'retweeted_status.user.friends_count': '904',
#    'retweeted_status.user.geo_enabled': 'false',
#    'retweeted_status.user.has_extended_profile': 'false',
#    'retweeted_status.user.id': '47539748',
#    'retweeted_status.user.id_str': '47539748',
#    'retweeted_status.user.is_translation_enabled': 'false',
#    'retweeted_status.user.is_translator': 'false',
#    'retweeted_status.user.lang': 'en',
#    'retweeted_status.user.listed_count': '5930',
#    'retweeted_status.user.location': 'Pasadena, CA',
#    'retweeted_status.user.name': 'Bill Gross',
#    'retweeted_status.user.notifications': 'false',
#    'retweeted_status.user.profile_background_color': 'C0DEED',
#    'retweeted_status.user.profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'retweeted_status.user.profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'retweeted_status.user.profile_background_tile': 'false',
#    'retweeted_status.user.profile_banner_url': 'https://pbs.twimg.com/profile_banners/47539748/1398394293',
#    'retweeted_status.user.profile_image_url': 'http://pbs.twimg.com/profile_images/264971169/Bill_Gross_Thumbnail_normal.jpg',
#    'retweeted_status.user.profile_image_url_https': 'https://pbs.twimg.com/profile_images/264971169/Bill_Gross_Thumbnail_normal.jpg',
#    'retweeted_status.user.profile_link_color': '0084B4',
#    'retweeted_status.user.profile_sidebar_border_color': 'C0DEED',
#    'retweeted_status.user.profile_sidebar_fill_color': 'DDEEF6',
#    'retweeted_status.user.profile_text_color': '333333',
#    'retweeted_status.user.profile_use_background_image': 'true',
#    'retweeted_status.user.protected': 'false',
#    'retweeted_status.user.screen_name': 'Bill_Gross',
#    'retweeted_status.user.statuses_count': '15846',
#    'retweeted_status.user.time_zone': 'null',
#    'retweeted_status.user.translator_type': 'none',
#    'retweeted_status.user.url': 'http://t.co/6lC0EBEbL6',
#    'retweeted_status.user.utc_offset': 'null',
#    'retweeted_status.user.verified': 'true',
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'srcjson': '{"retweeted_status":{"contributors":null,"text":"Amazing - and stunningly sad - pictures of before and after the #Tornado swept through #Joplin: http://j.mp/lfa80S from #Google street view.","geo":null,"retweeted":false,"in_reply_to_screen_name":null,"truncated":false,"lang":"en","entities":{"symbols":[],"urls":[],"hashtags":[{"text":"Tornado","indices":[64,72]},{"text":"Joplin","indices":[87,94]},{"text":"Google","indices":[120,127]}],"user_mentions":[]},"in_reply_to_status_id_str":null,"is_quote_status":false,"id":74632883578482688,"source":"<a href=\\"https://about.twitter.com/products/tweetdeck\\" rel=\\"nofollow\\">TweetDeck<\\/a>","in_reply_to_user_id_str":null,"favorited":false,"in_reply_to_status_id":null,"retweet_count":70,"created_at":"Sun May 29 00:27:20 +0000 2011","in_reply_to_user_id":null,"favorite_count":31,"id_str":"74632883578482688","place":null,"user":{"location":"Pasadena, CA","default_profile":false,"profile_background_tile":false,"statuses_count":15846,"lang":"en","profile_link_color":"0084B4","profile_banner_url":"https://pbs.twimg.com/profile_banners/47539748/1398394293","id":47539748,"following":false,"protected":false,"favourites_count":5299,"profile_text_color":"333333","description":"Founder of Technology Incubator Idealab and 100 companies in last 30 years. Tweeting while on my quest for learning in life and at conferences.","verified":true,"contributors_enabled":false,"profile_sidebar_border_color":"C0DEED","name":"Bill Gross","profile_background_color":"C0DEED","created_at":"Tue Jun 16 04:14:54 +0000 2009","is_translation_enabled":false,"default_profile_image":false,"followers_count":247367,"has_extended_profile":false,"profile_image_url_https":"https://pbs.twimg.com/profile_images/264971169/Bill_Gross_Thumbnail_normal.jpg","geo_enabled":false,"profile_background_image_url":"http://abs.twimg.com/images/themes/theme1/bg.png","profile_background_image_url_https":"https://abs.twimg.com/images/themes/theme1/bg.png","follow_request_sent":false,"entities":{"description":{"urls":[]},"url":{"urls":[{"expanded_url":"http://www.BillGross.com","indices":[0,22],"display_url":"BillGross.com","url":"http://t.co/6lC0EBEbL6"}]}},"url":"http://t.co/6lC0EBEbL6","utc_offset":null,"time_zone":null,"translator_type":"none","notifications":false,"profile_use_background_image":true,"friends_count":904,"profile_sidebar_fill_color":"DDEEF6","screen_name":"Bill_Gross","id_str":"47539748","profile_image_url":"http://pbs.twimg.com/profile_images/264971169/Bill_Gross_Thumbnail_normal.jpg","listed_count":5930,"is_translator":false},"coordinates":null},"contributors":null,"text":"RT @Bill_Gross: Amazing - and stunningly sad - pictures of before and after the #Tornado swept through #Joplin: http://j.mp/lfa80S from  ...","geo":null,"retweeted":false,"in_reply_to_screen_name":null,"truncated":false,"lang":"en","entities":{"symbols":[],"urls":[],"hashtags":[{"text":"Tornado","indices":[80,88]},{"text":"Joplin","indices":[103,110]}],"user_mentions":[{"id":47539748,"name":"Bill Gross","indices":[3,14],"screen_name":"Bill_Gross","id_str":"47539748"}]},"in_reply_to_status_id_str":null,"is_quote_status":false,"id":74920217951744000,"source":"<a href=\\"http://twitter.com\\" rel=\\"nofollow\\">Twitter Web Client<\\/a>","in_reply_to_user_id_str":null,"favorited":false,"in_reply_to_status_id":null,"retweet_count":70,"created_at":"Sun May 29 19:29:06 +0000 2011","in_reply_to_user_id":null,"favorite_count":0,"id_str":"74920217951744000","place":null,"user":{"location":"CT","default_profile":false,"profile_background_tile":false,"statuses_count":132842,"lang":"en","profile_link_color":"9B9DA1","profile_banner_url":"https://pbs.twimg.com/profile_banners/259468775/1481920399","id":259468775,"following":false,"protected":false,"favourites_count":48781,"profile_text_color":"3D1957","description":"I love this dumb ass @justinbieber //Abel \\u2022xo","verified":false,"contributors_enabled":false,"profile_sidebar_border_color":"FFFF ...
#    'text': 'RT @Bill_Gross: Amazing - and stunningly sad - pictures of before and after the #Tornado swept through #Joplin: http://j.mp/lfa80S from  ...',
#    'timestamp': '1306693746363',
#    'truncated': 'false',
#    'user.contributors_enabled': 'false',
#    'user.created_at': 'Tue Mar 01 23:59:47 +0000 2011',
#    'user.default_profile': 'false',
#    'user.default_profile_image': 'false',
#    'user.description': 'I love this dumb ass @justinbieber //Abel ?xo',
#    'user.entities.description.urls': '[]',
#    'user.entities.url.urls': '[{"expanded_url":"http://kidbiebers.tumblr.com/","indices":[0,23],"display_url":"kidbiebers.tumblr.com","url":"https://t.co/hFMyNcTzqD"}]',
#    'user.favourites_count': '48781',
#    'user.follow_request_sent': 'false',
#    'user.followers_count': '1669',
#    'user.following': 'false',
#    'user.friends_count': '322',
#    'user.geo_enabled': 'true',
#    'user.has_extended_profile': 'true',
#    'user.id': '259468775',
#    'user.id_str': '259468775',
#    'user.is_translation_enabled': 'false',
#    'user.is_translator': 'false',
#    'user.lang': 'en',
#    'user.listed_count': '40',
#    'user.location': 'CT',
#    'user.name': 'Natasha',
#    'user.notifications': 'false',
#    'user.profile_background_color': 'ABB8C2',
#    'user.profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#    'user.profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#    'user.profile_background_tile': 'false',
#    'user.profile_banner_url': 'https://pbs.twimg.com/profile_banners/259468775/1481920399',
#    'user.profile_image_url': 'http://pbs.twimg.com/profile_images/973614685592412164/YVYTei1j_normal.jpg',
#    'user.profile_image_url_https': 'https://pbs.twimg.com/profile_images/973614685592412164/YVYTei1j_normal.jpg',
#    'user.profile_link_color': '9B9DA1',
#    'user.profile_sidebar_border_color': 'FFFFFF',
#    'user.profile_sidebar_fill_color': '7AC3EE',
#    'user.profile_text_color': '3D1957',
#    'user.profile_use_background_image': 'false',
#    'user.protected': 'false',
#    'user.screen_name': 'itsNatashaF',
#    'user.statuses_count': '132842',
#    'user.time_zone': 'null',
#    'user.translator_type': 'regular',
#    'user.url': 'https://t.co/hFMyNcTzqD',
#    'user.utc_offset': 'null',
#    'user.verified': 'false'},
#   'score': 0.0,
#   'statisicalData': {'User Followers': 1669.0,
#    'User Follows': 322.0,
#    'User Statuses': 132842.0},
#   'text': 'RT @Bill_Gross: Amazing - and stunningly sad - pictures of before and after the #Tornado swept through #Joplin: http://j.mp/lfa80S from  ...',
#   'timestamp': 1306693746363,
#   'type': 'TWEETS'},
#  {'identifier': '77079355364343808',
#   'lang': 'en',
#   'location': {'description': None,
#    'geolocation': {'latitude': 39.1306, 'longitude': -84.52055399999999},
#    'identifier': None,
#    'name': 'Cincinnati (Hamilton County, Ohio, United States)',
#    'radius': 0.0},
#   'media': [],
#   'metadata': {'content': 'RT @velvetrasputin: The tornado damage in N. Minneapolis.   http://youtu.be/icvSJUWHHi0 -- damn... just glad my friends are all safe',
#    'contributors': 'null',
#    'coordinates': 'null',
#    'created_at': 'Sat Jun 04 18:28:45 +0000 2011',
#    'docno': '77079355364343808',
#    'entities.hashtags': '[]',
#    'entities.symbols': '[]',
#    'entities.urls': '[]',
#    'entities.user_mentions': '[]',
#    'favorite_count': '0',
#    'favorited': 'false',
#    'geo': 'null',
#    'id': '77079355364343808',
#    'id_str': '77079355364343808',
#    'in_reply_to_screen_name': 'null',
#    'in_reply_to_status_id': 'null',
#    'in_reply_to_status_id_str': 'null',
#    'in_reply_to_user_id': 'null',
#    'in_reply_to_user_id_str': 'null',
#    'is_quote_status': 'false',
#    'label': '???',
#    'lang': 'en',
#    'place': 'null',
#    'retweet_count': '0',
#    'retweeted': 'false',
#    'source': '<a href="http://www.twhirl.org" rel="nofollow">Seesmic twhirl</a>',
#    'srcjson': '{"contributors":null,"text":"RT @velvetrasputin: The tornado damage in N. Minneapolis.   http://youtu.be/icvSJUWHHi0 -- damn... just glad my friends are all safe","geo":null,"retweeted":false,"in_reply_to_screen_name":null,"truncated":false,"lang":"en","entities":{"symbols":[],"urls":[],"hashtags":[],"user_mentions":[]},"in_reply_to_status_id_str":null,"is_quote_status":false,"id":77079355364343808,"source":"<a href=\\"http://www.twhirl.org\\" rel=\\"nofollow\\">Seesmic twhirl<\\/a>","in_reply_to_user_id_str":null,"favorited":false,"in_reply_to_status_id":null,"retweet_count":0,"created_at":"Sat Jun 04 18:28:45 +0000 2011","in_reply_to_user_id":null,"favorite_count":0,"id_str":"77079355364343808","place":null,"user":{"location":"Cincinnati, Ohio","default_profile":false,"profile_background_tile":false,"statuses_count":25821,"lang":"en","profile_link_color":"1F98C7","profile_banner_url":"https://pbs.twimg.com/profile_banners/24076368/1452153960","id":24076368,"following":false,"protected":false,"favourites_count":174,"profile_text_color":"663B12","description":"Creative Entrepreneur","verified":false,"contributors_enabled":false,"profile_sidebar_border_color":"C6E2EE","name":"Emily Rose","profile_background_color":"C6E2EE","created_at":"Thu Mar 12 23:56:04 +0000 2009","is_translation_enabled":false,"default_profile_image":false,"followers_count":674,"has_extended_profile":true,"profile_image_url_https":"https://pbs.twimg.com/profile_images/567599710873993217/J7BAtVP9_normal.jpeg","geo_enabled":false,"profile_background_image_url":"http://abs.twimg.com/images/themes/theme2/bg.gif","profile_background_image_url_https":"https://abs.twimg.com/images/themes/theme2/bg.gif","follow_request_sent":false,"entities":{"description":{"urls":[]},"url":{"urls":[{"expanded_url":"http://about.me/emilyrosetheartist","indices":[0,22],"display_url":"about.me/emilyrosethear\\u2026","url":"http://t.co/8FSb3vlA40"}]}},"url":"http://t.co/8FSb3vlA40","utc_offset":null,"time_zone":null,"translator_type":"none","notifications":false,"profile_use_background_image":true,"friends_count":200,"profile_sidebar_fill_color":"DAECF4","screen_name":"emilyroseartist","id_str":"24076368","profile_image_url":"http://pbs.twimg.com/profile_images/567599710873993217/J7BAtVP9_normal.jpeg","listed_count":40,"is_translator":false},"coordinates":null}',
#    'text': 'RT @velvetrasputin: The tornado damage in N. Minneapolis.   http://youtu.be/icvSJUWHHi0 -- damn... just glad my friends are all safe',
#    'timestamp': '1307208525364',
#    'truncated': 'false',
#    'user.contributors_enabled': 'false',
#    'user.created_at': 'Thu Mar 12 23:56:04 +0000 2009',
#    'user.default_profile': 'false',
#    'user.default_profile_image': 'false',
#    'user.description': 'Creative Entrepreneur',
#    'user.entities.description.urls': '[]',
#    'user.entities.url.urls': '[{"expanded_url":"http://about.me/emilyrosetheartist","indices":[0,22],"display_url":"about.me/emilyrosethear?","url":"http://t.co/8FSb3vlA40"}]',
#    'user.favourites_count': '174',
#    'user.follow_request_sent': 'false',
#    'user.followers_count': '674',
#    'user.following': 'false',
#    'user.friends_count': '200',
#    'user.geo_enabled': 'false',
#    'user.has_extended_profile': 'true',
#    'user.id': '24076368',
#    'user.id_str': '24076368',
#    'user.is_translation_enabled': 'false',
#    'user.is_translator': 'false',
#    'user.lang': 'en',
#    'user.listed_count': '40',
#    'user.location': 'Cincinnati, Ohio',
#    'user.name': 'Emily Rose',
#    'user.notifications': 'false',
#    'user.profile_background_color': 'C6E2EE',
#    'user.profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#    'user.profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#    'user.profile_background_tile': 'false',
#    'user.profile_banner_url': 'https://pbs.twimg.com/profile_banners/24076368/1452153960',
#    'user.profile_image_url': 'http://pbs.twimg.com/profile_images/567599710873993217/J7BAtVP9_normal.jpeg',
#    'user.profile_image_url_https': 'https://pbs.twimg.com/profile_images/567599710873993217/J7BAtVP9_normal.jpeg',
#    'user.profile_link_color': '1F98C7',
#    'user.profile_sidebar_border_color': 'C6E2EE',
#    'user.profile_sidebar_fill_color': 'DAECF4',
#    'user.profile_text_color': '663B12',
#    'user.profile_use_background_image': 'true',
#    'user.protected': 'false',
#    'user.screen_name': 'emilyroseartist',
#    'user.statuses_count': '25821',
#    'user.time_zone': 'null',
#    'user.translator_type': 'none',
#    'user.url': 'http://t.co/8FSb3vlA40',
#    'user.utc_offset': 'null',
#    'user.verified': 'false'},
#   'score': 0.0,
#   'statisicalData': {'User Followers': 674.0,
#    'User Follows': 200.0,
#    'User Statuses': 25821.0},
#   'text': 'RT @velvetrasputin: The tornado damage in N. Minneapolis.   http://youtu.be/icvSJUWHHi0 -- damn... just glad my friends are all safe',
#   'timestamp': 1307208525364,
#   'type': 'TWEETS'},
#  {'identifier': '74304399119351808',
#   'lang': 'en',
#   'location': {'description': None,
#    'geolocation': {'latitude': -31.934566, 'longitude': 136.09991499999998},
#    'identifier': None,
#    'name': 'Australia',
#    'radius': 0.0},
#   'media': [],
#   'metadata': {'content': 'RT @CrossCzech17: A tornado kills 125 innocent people in Joplin.  One week later, Westboro Baptist Church protests in Joplin.  God - you ...',
#    'contributors': 'null',
#    'coordinates': 'null',
#    'created_at': 'Sat May 28 02:42:03 +0000 2011',
#    'docno': '74304399119351808',
#    'entities.hashtags': '[]',
#    'entities.symbols': '[]',
#    'entities.urls': '[]',
#    'entities.user_mentions': '[]',
#    'favorite_count': '0',
#    'favorited': 'false',
#    'geo': 'null',
#    'id': '74304399119351808',
#    'id_str': '74304399119351808',
#    'in_reply_to_screen_name': 'null',
#    'in_reply_to_status_id': 'null',
#    'in_reply_to_status_id_str': 'null',
#    'in_reply_to_user_id': 'null',
#    'in_reply_to_user_id_str': 'null',
#    'is_quote_status': 'false',
#    'label': '???',
#    'lang': 'en',
#    'place': 'null',
#    'retweet_count': '26',
#    'retweeted': 'false',
#    'retweeted_status.contributors': 'null',
#    'retweeted_status.coordinates': 'null',
#    'retweeted_status.created_at': 'Fri May 27 17:43:46 +0000 2011',
#    'retweeted_status.entities.hashtags': '[]',
#    'retweeted_status.entities.symbols': '[]',
#    'retweeted_status.entities.urls': '[]',
#    'retweeted_status.entities.user_mentions': '[]',
#    'retweeted_status.favorite_count': '75',
#    'retweeted_status.favorited': 'false',
#    'retweeted_status.geo': 'null',
#    'retweeted_status.id': '74168932776423425',
#    'retweeted_status.id_str': '74168932776423425',
#    'retweeted_status.in_reply_to_screen_name': 'null',
#    'retweeted_status.in_reply_to_status_id': 'null',
#    'retweeted_status.in_reply_to_status_id_str': 'null',
#    'retweeted_status.in_reply_to_user_id': 'null',
#    'retweeted_status.in_reply_to_user_id_str': 'null',
#    'retweeted_status.is_quote_status': 'false',
#    'retweeted_status.lang': 'en',
#    'retweeted_status.place': 'null',
#    'retweeted_status.retweet_count': '26',
#    'retweeted_status.retweeted': 'false',
#    'retweeted_status.source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'retweeted_status.text': 'A tornado kills 125 innocent people in Joplin.  One week later, Westboro Baptist Church protests in Joplin.  God - you were off by 7 days.',
#    'retweeted_status.truncated': 'false',
#    'retweeted_status.user.contributors_enabled': 'false',
#    'retweeted_status.user.created_at': 'Thu Sep 02 00:42:05 +0000 2010',
#    'retweeted_status.user.default_profile': 'false',
#    'retweeted_status.user.default_profile_image': 'false',
#    'retweeted_status.user.description': 'Is the piano a string instrument or a percussion instrument? The surprising answer - no one gives a crap.',
#    'retweeted_status.user.entities.description.urls': '[]',
#    'retweeted_status.user.entities.url.urls': '[{"expanded_url":"http://twtrland.com/profile/CoatCzech","indices":[0,23],"display_url":"twtrland.com/profile/CoatCz?","url":"https://t.co/7ItGc4YE7K"}]',
#    'retweeted_status.user.favourites_count': '171850',
#    'retweeted_status.user.follow_request_sent': 'false',
#    'retweeted_status.user.followers_count': '4806',
#    'retweeted_status.user.following': 'false',
#    'retweeted_status.user.friends_count': '427',
#    'retweeted_status.user.geo_enabled': 'false',
#    'retweeted_status.user.has_extended_profile': 'false',
#    'retweeted_status.user.id': '185860787',
#    'retweeted_status.user.id_str': '185860787',
#    'retweeted_status.user.is_translation_enabled': 'false',
#    'retweeted_status.user.is_translator': 'false',
#    'retweeted_status.user.lang': 'en',
#    'retweeted_status.user.listed_count': '491',
#    'retweeted_status.user.location': 'St. Louis',
#    'retweeted_status.user.name': 'Steve Svehla',
#    'retweeted_status.user.notifications': 'false',
#    'retweeted_status.user.profile_background_color': '567382',
#    'retweeted_status.user.profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'retweeted_status.user.profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'retweeted_status.user.profile_background_tile': 'false',
#    'retweeted_status.user.profile_banner_url': 'https://pbs.twimg.com/profile_banners/185860787/1442456277',
#    'retweeted_status.user.profile_image_url': 'http://pbs.twimg.com/profile_images/964733717162979328/Z72rWb6j_normal.jpg',
#    'retweeted_status.user.profile_image_url_https': 'https://pbs.twimg.com/profile_images/964733717162979328/Z72rWb6j_normal.jpg',
#    'retweeted_status.user.profile_link_color': '4A913C',
#    'retweeted_status.user.profile_sidebar_border_color': 'C0DEED',
#    'retweeted_status.user.profile_sidebar_fill_color': 'DDEEF6',
#    'retweeted_status.user.profile_text_color': '0F050F',
#    'retweeted_status.user.profile_use_background_image': 'true',
#    'retweeted_status.user.protected': 'false',
#    'retweeted_status.user.screen_name': 'CoatCzech',
#    'retweeted_status.user.statuses_count': '4173',
#    'retweeted_status.user.time_zone': 'null',
#    'retweeted_status.user.translator_type': 'none',
#    'retweeted_status.user.url': 'https://t.co/7ItGc4YE7K',
#    'retweeted_status.user.utc_offset': 'null',
#    'retweeted_status.user.verified': 'false',
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'srcjson': '{"retweeted_status":{"contributors":null,"text":"A tornado kills 125 innocent people in Joplin.  One week later, Westboro Baptist Church protests in Joplin.  God - you were off by 7 days.","geo":null,"retweeted":false,"in_reply_to_screen_name":null,"truncated":false,"lang":"en","entities":{"symbols":[],"urls":[],"hashtags":[],"user_mentions":[]},"in_reply_to_status_id_str":null,"is_quote_status":false,"id":74168932776423425,"source":"<a href=\\"http://twitter.com\\" rel=\\"nofollow\\">Twitter Web Client<\\/a>","in_reply_to_user_id_str":null,"favorited":false,"in_reply_to_status_id":null,"retweet_count":26,"created_at":"Fri May 27 17:43:46 +0000 2011","in_reply_to_user_id":null,"favorite_count":75,"id_str":"74168932776423425","place":null,"user":{"location":"St. Louis","default_profile":false,"profile_background_tile":false,"statuses_count":4173,"lang":"en","profile_link_color":"4A913C","profile_banner_url":"https://pbs.twimg.com/profile_banners/185860787/1442456277","id":185860787,"following":false,"protected":false,"favourites_count":171850,"profile_text_color":"0F050F","description":"Is the piano a string instrument or a percussion instrument? The surprising answer - no one gives a crap.","verified":false,"contributors_enabled":false,"profile_sidebar_border_color":"C0DEED","name":"Steve Svehla","profile_background_color":"567382","created_at":"Thu Sep 02 00:42:05 +0000 2010","is_translation_enabled":false,"default_profile_image":false,"followers_count":4806,"has_extended_profile":false,"profile_image_url_https":"https://pbs.twimg.com/profile_images/964733717162979328/Z72rWb6j_normal.jpg","geo_enabled":false,"profile_background_image_url":"http://abs.twimg.com/images/themes/theme1/bg.png","profile_background_image_url_https":"https://abs.twimg.com/images/themes/theme1/bg.png","follow_request_sent":false,"entities":{"description":{"urls":[]},"url":{"urls":[{"expanded_url":"http://twtrland.com/profile/CoatCzech","indices":[0,23],"display_url":"twtrland.com/profile/CoatCz\\u2026","url":"https://t.co/7ItGc4YE7K"}]}},"url":"https://t.co/7ItGc4YE7K","utc_offset":null,"time_zone":null,"translator_type":"none","notifications":false,"profile_use_background_image":true,"friends_count":427,"profile_sidebar_fill_color":"DDEEF6","screen_name":"CoatCzech","id_str":"185860787","profile_image_url":"http://pbs.twimg.com/profile_images/964733717162979328/Z72rWb6j_normal.jpg","listed_count":491,"is_translator":false},"coordinates":null},"contributors":null,"text":"RT @CrossCzech17: A tornado kills 125 innocent people in Joplin.  One week later, Westboro Baptist Church protests in Joplin.  God - you ...","geo":null,"retweeted":false,"in_reply_to_screen_name":null,"truncated":false,"lang":"en","entities":{"symbols":[],"urls":[],"hashtags":[],"user_mentions":[]},"in_reply_to_status_id_str":null,"is_quote_status":false,"id":74304399119351808,"source":"<a href=\\"http://twitter.com/download/iphone\\" rel=\\"nofollow\\">Twitter for iPhone<\\/a>","in_reply_to_user_id_str":null,"favorited":false,"in_reply_to_status_id":null,"retweet_count":26,"created_at":"Sat May 28 02:42:03 +0000 2011","in_reply_to_user_id":null,"favorite_count":0,"id_str":"74304399119351808","place":null,"user":{"location":"Australia","default_profile":false,"profile_background_tile":false,"statuses_count":10716,"lang":"en","profile_link_color":"DD2E44","profile_banner_url":"https://pbs.twimg.com/profile_banners/218045705/1474834830","id":218045705,"following":false,"protected":false,"favourites_count":6872,"profile_text_color":"333333","description":"a thin, scruffy man cat trapped in the body of a fat, middle aged lady","verified":false,"contributors_enabled":false,"profile_sidebar_border_color":"C0DEED","name":"sam hell","profile_background_color":"FFF04D","created_at":"Sun Nov 21 08:00:24 +0000 2010","is_translation_enabled":false,"default_profile_image":false,"followers_count":99,"has_extended_profile":false,"profile_image_url_https":"https://pbs.twimg.com/profil ...
#    'text': 'RT @CrossCzech17: A tornado kills 125 innocent people in Joplin.  One week later, Westboro Baptist Church protests in Joplin.  God - you ...',
#    'timestamp': '1306546923365',
#    'truncated': 'false',
#    'user.contributors_enabled': 'false',
#    'user.created_at': 'Sun Nov 21 08:00:24 +0000 2010',
#    'user.default_profile': 'false',
#    'user.default_profile_image': 'false',
#    'user.description': 'a thin, scruffy man cat trapped in the body of a fat, middle aged lady',
#    'user.entities.description.urls': '[]',
#    'user.favourites_count': '6872',
#    'user.follow_request_sent': 'false',
#    'user.followers_count': '99',
#    'user.following': 'false',
#    'user.friends_count': '70',
#    'user.geo_enabled': 'false',
#    'user.has_extended_profile': 'false',
#    'user.id': '218045705',
#    'user.id_str': '218045705',
#    'user.is_translation_enabled': 'false',
#    'user.is_translator': 'false',
#    'user.lang': 'en',
#    'user.listed_count': '2',
#    'user.location': 'Australia',
#    'user.name': 'sam hell',
#    'user.notifications': 'false',
#    'user.profile_background_color': 'FFF04D',
#    'user.profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'user.profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'user.profile_background_tile': 'false',
#    'user.profile_banner_url': 'https://pbs.twimg.com/profile_banners/218045705/1474834830',
#    'user.profile_image_url': 'http://pbs.twimg.com/profile_images/751376888581480448/vWS8dpti_normal.jpg',
#    'user.profile_image_url_https': 'https://pbs.twimg.com/profile_images/751376888581480448/vWS8dpti_normal.jpg',
#    'user.profile_link_color': 'DD2E44',
#    'user.profile_sidebar_border_color': 'C0DEED',
#    'user.profile_sidebar_fill_color': 'DDEEF6',
#    'user.profile_text_color': '333333',
#    'user.profile_use_background_image': 'true',
#    'user.protected': 'false',
#    'user.screen_name': 'felislupin',
#    'user.statuses_count': '10716',
#    'user.time_zone': 'null',
#    'user.translator_type': 'none',
#    'user.url': 'null',
#    'user.utc_offset': 'null',
#    'user.verified': 'false'},
#   'score': 0.0,
#   'statisicalData': {'User Followers': 99.0,
#    'User Follows': 70.0,
#    'User Statuses': 10716.0},
#   'text': 'RT @CrossCzech17: A tornado kills 125 innocent people in Joplin.  One week later, Westboro Baptist Church protests in Joplin.  God - you ...',
#   'timestamp': 1306546923365,
#   'type': 'TWEETS'},
#  {'identifier': '77720662453649408',
#   'lang': 'en',
#   'location': None,
#   'media': [],
#   'metadata': {'content': 'Death toll from Joplin tornado rises to 141: officials - Reuters http://reut.rs/jw1E4Z',
#    'contributors': 'null',
#    'coordinates': 'null',
#    'created_at': 'Mon Jun 06 12:57:04 +0000 2011',
#    'docno': '77720662453649408',
#    'entities.hashtags': '[]',
#    'entities.symbols': '[]',
#    'entities.urls': '[]',
#    'entities.user_mentions': '[]',
#    'favorite_count': '0',
#    'favorited': 'false',
#    'geo': 'null',
#    'id': '77720662453649408',
#    'id_str': '77720662453649408',
#    'in_reply_to_screen_name': 'null',
#    'in_reply_to_status_id': 'null',
#    'in_reply_to_status_id_str': 'null',
#    'in_reply_to_user_id': 'null',
#    'in_reply_to_user_id_str': 'null',
#    'is_quote_status': 'false',
#    'label': '???',
#    'lang': 'en',
#    'place': 'null',
#    'retweet_count': '0',
#    'retweeted': 'false',
#    'source': '<a href="http://twitterfeed.com" rel="nofollow">twitterfeed</a>',
#    'srcjson': '{"contributors":null,"text":"Death toll from Joplin tornado rises to 141: officials - Reuters http://reut.rs/jw1E4Z","geo":null,"retweeted":false,"in_reply_to_screen_name":null,"truncated":false,"lang":"en","entities":{"symbols":[],"urls":[],"hashtags":[],"user_mentions":[]},"in_reply_to_status_id_str":null,"is_quote_status":false,"id":77720662453649408,"source":"<a href=\\"http://twitterfeed.com\\" rel=\\"nofollow\\">twitterfeed<\\/a>","in_reply_to_user_id_str":null,"favorited":false,"in_reply_to_status_id":null,"retweet_count":0,"created_at":"Mon Jun 06 12:57:04 +0000 2011","in_reply_to_user_id":null,"favorite_count":0,"id_str":"77720662453649408","place":null,"user":{"location":"","default_profile":false,"profile_background_tile":false,"statuses_count":33546,"lang":"en","profile_link_color":"004376","profile_banner_url":"https://pbs.twimg.com/profile_banners/265767423/1525274519","id":265767423,"following":false,"protected":false,"favourites_count":56,"profile_text_color":"000000","description":"Unsponsored curated #ICO News: #InitialCoinOffering #TokenSale #Blockchain #Cryptocurrency","verified":false,"contributors_enabled":false,"profile_sidebar_border_color":"EFEFEF","name":"New Blockchains","profile_background_color":"FFFFFF","created_at":"Mon Mar 14 03:29:46 +0000 2011","is_translation_enabled":false,"default_profile_image":false,"followers_count":307,"has_extended_profile":false,"profile_image_url_https":"https://pbs.twimg.com/profile_images/991720231054659584/hSqlzdQP_normal.jpg","geo_enabled":false,"profile_background_image_url":"http://abs.twimg.com/images/themes/theme1/bg.png","profile_background_image_url_https":"https://abs.twimg.com/images/themes/theme1/bg.png","follow_request_sent":false,"entities":{"description":{"urls":[]}},"url":null,"utc_offset":null,"time_zone":null,"translator_type":"none","notifications":false,"profile_use_background_image":true,"friends_count":14,"profile_sidebar_fill_color":"EFEFEF","screen_name":"NewBlockchains","id_str":"265767423","profile_image_url":"http://pbs.twimg.com/profile_images/991720231054659584/hSqlzdQP_normal.jpg","listed_count":4,"is_translator":false},"coordinates":null}',
#    'text': 'Death toll from Joplin tornado rises to 141: officials - Reuters http://reut.rs/jw1E4Z',
#    'timestamp': '1307361424365',
#    'truncated': 'false',
#    'user.contributors_enabled': 'false',
#    'user.created_at': 'Mon Mar 14 03:29:46 +0000 2011',
#    'user.default_profile': 'false',
#    'user.default_profile_image': 'false',
#    'user.description': 'Unsponsored curated #ICO News: #InitialCoinOffering #TokenSale #Blockchain #Cryptocurrency',
#    'user.entities.description.urls': '[]',
#    'user.favourites_count': '56',
#    'user.follow_request_sent': 'false',
#    'user.followers_count': '307',
#    'user.following': 'false',
#    'user.friends_count': '14',
#    'user.geo_enabled': 'false',
#    'user.has_extended_profile': 'false',
#    'user.id': '265767423',
#    'user.id_str': '265767423',
#    'user.is_translation_enabled': 'false',
#    'user.is_translator': 'false',
#    'user.lang': 'en',
#    'user.listed_count': '4',
#    'user.location': '',
#    'user.name': 'New Blockchains',
#    'user.notifications': 'false',
#    'user.profile_background_color': 'FFFFFF',
#    'user.profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'user.profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'user.profile_background_tile': 'false',
#    'user.profile_banner_url': 'https://pbs.twimg.com/profile_banners/265767423/1525274519',
#    'user.profile_image_url': 'http://pbs.twimg.com/profile_images/991720231054659584/hSqlzdQP_normal.jpg',
#    'user.profile_image_url_https': 'https://pbs.twimg.com/profile_images/991720231054659584/hSqlzdQP_normal.jpg',
#    'user.profile_link_color': '004376',
#    'user.profile_sidebar_border_color': 'EFEFEF',
#    'user.profile_sidebar_fill_color': 'EFEFEF',
#    'user.profile_text_color': '000000',
#    'user.profile_use_background_image': 'true',
#    'user.protected': 'false',
#    'user.screen_name': 'NewBlockchains',
#    'user.statuses_count': '33546',
#    'user.time_zone': 'null',
#    'user.translator_type': 'none',
#    'user.url': 'null',
#    'user.utc_offset': 'null',
#    'user.verified': 'false'},
#   'score': 0.0,
#   'statisicalData': {'User Followers': 307.0,
#    'User Follows': 14.0,
#    'User Statuses': 33546.0},
#   'text': 'Death toll from Joplin tornado rises to 141: officials - Reuters http://reut.rs/jw1E4Z',
#   'timestamp': 1307361424365,
#   'type': 'TWEETS'},
#  {'identifier': '73023697123938304',
#   'lang': 'en',
#   'location': None,
#   'media': [],
#   'metadata': {'content': 'RT @feedthechildren Help disaster victims at http://www.feedthechildren.org/disasterrelief #mo #tornado #pray',
#    'contributors': 'null',
#    'coordinates': 'null',
#    'created_at': 'Tue May 24 13:53:00 +0000 2011',
#    'docno': '73023697123938304',
#    'entities.hashtags': '[{"text":"mo","indices":[91,94]},{"text":"tornado","indices":[95,103]},{"text":"pray","indices":[104,109]}]',
#    'entities.symbols': '[]',
#    'entities.urls': '[]',
#    'entities.user_mentions': '[{"id":17602585,"name":"Feed the Children","indices":[3,19],"screen_name":"feedthechildren","id_str":"17602585"}]',
#    'favorite_count': '0',
#    'favorited': 'false',
#    'geo': 'null',
#    'id': '73023697123938304',
#    'id_str': '73023697123938304',
#    'in_reply_to_screen_name': 'null',
#    'in_reply_to_status_id': 'null',
#    'in_reply_to_status_id_str': 'null',
#    'in_reply_to_user_id': 'null',
#    'in_reply_to_user_id_str': 'null',
#    'is_quote_status': 'false',
#    'label': '???',
#    'lang': 'en',
#    'place': 'null',
#    'retweet_count': '0',
#    'retweeted': 'false',
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'srcjson': '{"contributors":null,"text":"RT @feedthechildren Help disaster victims at http://www.feedthechildren.org/disasterrelief #mo #tornado #pray","geo":null,"retweeted":false,"in_reply_to_screen_name":null,"truncated":false,"lang":"en","entities":{"symbols":[],"urls":[],"hashtags":[{"text":"mo","indices":[91,94]},{"text":"tornado","indices":[95,103]},{"text":"pray","indices":[104,109]}],"user_mentions":[{"id":17602585,"name":"Feed the Children","indices":[3,19],"screen_name":"feedthechildren","id_str":"17602585"}]},"in_reply_to_status_id_str":null,"is_quote_status":false,"id":73023697123938304,"source":"<a href=\\"http://twitter.com\\" rel=\\"nofollow\\">Twitter Web Client<\\/a>","in_reply_to_user_id_str":null,"favorited":false,"in_reply_to_status_id":null,"retweet_count":0,"created_at":"Tue May 24 13:53:00 +0000 2011","in_reply_to_user_id":null,"favorite_count":0,"id_str":"73023697123938304","place":null,"user":{"location":"","default_profile":false,"profile_background_tile":false,"statuses_count":146874,"lang":"en","profile_link_color":"0084B4","id":18204604,"following":false,"protected":false,"favourites_count":13965,"profile_text_color":"333333","description":"Cattle Rancher and cultural commentator","verified":false,"contributors_enabled":false,"profile_sidebar_border_color":"BDDCAD","name":"Melissa","profile_background_color":"9AE4E8","created_at":"Thu Dec 18 00:43:39 +0000 2008","is_translation_enabled":false,"default_profile_image":false,"followers_count":4846,"has_extended_profile":false,"profile_image_url_https":"https://pbs.twimg.com/profile_images/287456376/out_house_normal.jpg","geo_enabled":true,"profile_background_image_url":"http://abs.twimg.com/images/themes/theme1/bg.png","profile_background_image_url_https":"https://abs.twimg.com/images/themes/theme1/bg.png","follow_request_sent":false,"entities":{"description":{"urls":[]}},"url":null,"utc_offset":null,"time_zone":null,"translator_type":"none","notifications":false,"profile_use_background_image":true,"friends_count":4508,"profile_sidebar_fill_color":"DDFFCC","screen_name":"MLAS","id_str":"18204604","profile_image_url":"http://pbs.twimg.com/profile_images/287456376/out_house_normal.jpg","listed_count":353,"is_translator":false},"coordinates":null}',
#    'text': 'RT @feedthechildren Help disaster victims at http://www.feedthechildren.org/disasterrelief #mo #tornado #pray',
#    'timestamp': '1306241580367',
#    'truncated': 'false',
#    'user.contributors_enabled': 'false',
#    'user.created_at': 'Thu Dec 18 00:43:39 +0000 2008',
#    'user.default_profile': 'false',
#    'user.default_profile_image': 'false',
#    'user.description': 'Cattle Rancher and cultural commentator',
#    'user.entities.description.urls': '[]',
#    'user.favourites_count': '13965',
#    'user.follow_request_sent': 'false',
#    'user.followers_count': '4846',
#    'user.following': 'false',
#    'user.friends_count': '4508',
#    'user.geo_enabled': 'true',
#    'user.has_extended_profile': 'false',
#    'user.id': '18204604',
#    'user.id_str': '18204604',
#    'user.is_translation_enabled': 'false',
#    'user.is_translator': 'false',
#    'user.lang': 'en',
#    'user.listed_count': '353',
#    'user.location': '',
#    'user.name': 'Melissa',
#    'user.notifications': 'false',
#    'user.profile_background_color': '9AE4E8',
#    'user.profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'user.profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'user.profile_background_tile': 'false',
#    'user.profile_image_url': 'http://pbs.twimg.com/profile_images/287456376/out_house_normal.jpg',
#    'user.profile_image_url_https': 'https://pbs.twimg.com/profile_images/287456376/out_house_normal.jpg',
#    'user.profile_link_color': '0084B4',
#    'user.profile_sidebar_border_color': 'BDDCAD',
#    'user.profile_sidebar_fill_color': 'DDFFCC',
#    'user.profile_text_color': '333333',
#    'user.profile_use_background_image': 'true',
#    'user.protected': 'false',
#    'user.screen_name': 'MLAS',
#    'user.statuses_count': '146874',
#    'user.time_zone': 'null',
#    'user.translator_type': 'none',
#    'user.url': 'null',
#    'user.utc_offset': 'null',
#    'user.verified': 'false'},
#   'score': 0.0,
#   'statisicalData': {'User Followers': 4846.0,
#    'User Follows': 4508.0,
#    'User Statuses': 146874.0},
#   'text': 'RT @feedthechildren Help disaster victims at http://www.feedthechildren.org/disasterrelief #mo #tornado #pray',
#   'timestamp': 1306241580367,
#   'type': 'TWEETS'},
#  {'identifier': '75424812020936704',
#   'lang': 'en',
#   'location': {'description': None,
#    'geolocation': {'latitude': 33.747420999999996, 'longitude': -84.412048},
#    'identifier': None,
# ...
#    'text': 'Obama | President | Tornado | Barack | Missouri - http://thenewsportal.net/?p=962817 #news',
#    'timestamp': '1306741325097',
#    'truncated': 'false',
#    'user.contributors_enabled': 'false',
#    'user.created_at': 'Tue Apr 27 01:33:54 +0000 2010',
#    'user.default_profile': 'false',
#    'user.default_profile_image': 'false',
#    'user.description': '',
#    'user.entities.description.urls': '[]',
#    'user.favourites_count': '1',
#    'user.follow_request_sent': 'false',
#    'user.followers_count': '13825',
#    'user.following': 'false',
#    'user.friends_count': '16644',
#    'user.geo_enabled': 'false',
#    'user.has_extended_profile': 'false',
#    'user.id': '137538421',
#    'user.id_str': '137538421',
#    'user.is_translation_enabled': 'false',
#    'user.is_translator': 'false',
#    'user.lang': 'en',
#    'user.listed_count': '421',
#    'user.location': 'London, UK',
#    'user.name': 'Lazy Bunny Music',
#    'user.notifications': 'false',
#    'user.profile_background_color': 'FFFFFF',
#    'user.profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'user.profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'user.profile_background_tile': 'false',
#    'user.profile_banner_url': 'https://pbs.twimg.com/profile_banners/137538421/1359643776',
#    'user.profile_image_url': 'http://pbs.twimg.com/profile_images/3175787305/85e971f65e1e200a9f76357f853dd274_normal.jpeg',
#    'user.profile_image_url_https': 'https://pbs.twimg.com/profile_images/3175787305/85e971f65e1e200a9f76357f853dd274_normal.jpeg',
#    'user.profile_link_color': '9AE4E8',
#    'user.profile_sidebar_border_color': 'FFFFFF',
#    'user.profile_sidebar_fill_color': 'FFFFFF',
#    'user.profile_text_color': '000000',
#    'user.profile_use_background_image': 'true',
#    'user.protected': 'false',
#    'user.screen_name': 'LazyBunnyMusic',
#    'user.statuses_count': '99081',
#    'user.time_zone': 'null',
#    'user.translator_type': 'none',
#    'user.url': 'null',
#    'user.utc_offset': 'null',
#    'user.verified': 'false'},
#   'score': 0.0,
#   'statisicalData': {'User Followers': 13825.0,
#    'User Follows': 16644.0,
#    'User Statuses': 99081.0},
#   'text': 'Obama | President | Tornado | Barack | Missouri - http://thenewsportal.net/?p=962817 #news',
#   'timestamp': 1306741325097,
#   'type': 'TWEETS'},
#  {'identifier': '73454830265442304',
#   'lang': 'en',
#   'location': {'description': None,
#    'geolocation': {'latitude': 32.22032, 'longitude': -98.201954},
#    'identifier': None,
#    'name': 'Stephenville (Erath County, Texas, United States)',
#    'radius': 0.0},
#   'media': [],
#   'metadata': {'content': 'SPC Tornado Watch 368 Status Reports http://dlvr.it/SzjZv',
#    'contributors': 'null',
#    'coordinates': 'null',
#    'created_at': 'Wed May 25 18:26:10 +0000 2011',
#    'docno': '73454830265442304',
#    'entities.hashtags': '[]',
#    'entities.symbols': '[]',
#    'entities.urls': '[]',
#    'entities.user_mentions': '[]',
#    'favorite_count': '0',
#    'favorited': 'false',
#    'geo': 'null',
#    'id': '73454830265442304',
#    'id_str': '73454830265442304',
#    'in_reply_to_screen_name': 'null',
#    'in_reply_to_status_id': 'null',
#    'in_reply_to_status_id_str': 'null',
#    'in_reply_to_user_id': 'null',
#    'in_reply_to_user_id_str': 'null',
#    'is_quote_status': 'false',
#    'label': '???',
#    'lang': 'en',
#    'place': 'null',
#    'retweet_count': '0',
#    'retweeted': 'false',
#    'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#    'srcjson': '{"contributors":null,"text":"SPC Tornado Watch 368 Status Reports http://dlvr.it/SzjZv","geo":null,"retweeted":false,"in_reply_to_screen_name":null,"truncated":false,"lang":"en","entities":{"symbols":[],"urls":[],"hashtags":[],"user_mentions":[]},"in_reply_to_status_id_str":null,"is_quote_status":false,"id":73454830265442304,"source":"<a href=\\"https://dlvrit.com/\\" rel=\\"nofollow\\">dlvr.it<\\/a>","in_reply_to_user_id_str":null,"favorited":false,"in_reply_to_status_id":null,"retweet_count":0,"created_at":"Wed May 25 18:26:10 +0000 2011","in_reply_to_user_id":null,"favorite_count":0,"id_str":"73454830265442304","place":null,"user":{"location":"Stephenville, TX","default_profile":false,"profile_background_tile":true,"statuses_count":205375,"lang":"en","profile_link_color":"9266CC","id":25020797,"following":false,"protected":false,"favourites_count":439,"profile_text_color":"666666","description":"Tarleton State University PROUD TARLETON TEXAN Life moves pretty fast. If you don\'t stop and look around once in a while, you could miss it.-Ferris Bueller","verified":false,"contributors_enabled":false,"profile_sidebar_border_color":"FFFFFF","name":"Chris Garner","profile_background_color":"9266CC","created_at":"Wed Mar 18 03:32:25 +0000 2009","is_translation_enabled":false,"default_profile_image":false,"followers_count":1337,"has_extended_profile":true,"profile_image_url_https":"https://pbs.twimg.com/profile_images/810887357260058624/Zx4EKTR9_normal.jpg","geo_enabled":true,"profile_background_image_url":"http://abs.twimg.com/images/themes/theme15/bg.png","profile_background_image_url_https":"https://abs.twimg.com/images/themes/theme15/bg.png","follow_request_sent":false,"entities":{"description":{"urls":[]}},"url":null,"utc_offset":null,"time_zone":null,"translator_type":"none","notifications":false,"profile_use_background_image":false,"friends_count":663,"profile_sidebar_fill_color":"252429","screen_name":"Chris_Garner1","id_str":"25020797","profile_image_url":"http://pbs.twimg.com/profile_images/810887357260058624/Zx4EKTR9_normal.jpg","listed_count":40,"is_translator":false},"coordinates":null}',
#    'text': 'SPC Tornado Watch 368 Status Reports http://dlvr.it/SzjZv',
#    'timestamp': '1306344370097',
#    'truncated': 'false',
#    'user.contributors_enabled': 'false',
#    'user.created_at': 'Wed Mar 18 03:32:25 +0000 2009',
#    'user.default_profile': 'false',
#    'user.default_profile_image': 'false',
#    'user.description': "Tarleton State University PROUD TARLETON TEXAN Life moves pretty fast. If you don't stop and look around once in a while, you could miss it.-Ferris Bueller",
#    'user.entities.description.urls': '[]',
#    'user.favourites_count': '439',
#    'user.follow_request_sent': 'false',
#    'user.followers_count': '1337',
#    'user.following': 'false',
#    'user.friends_count': '663',
#    'user.geo_enabled': 'true',
#    'user.has_extended_profile': 'true',
#    'user.id': '25020797',
#    'user.id_str': '25020797',
#    'user.is_translation_enabled': 'false',
#    'user.is_translator': 'false',
#    'user.lang': 'en',
#    'user.listed_count': '40',
#    'user.location': 'Stephenville, TX',
#    'user.name': 'Chris Garner',
#    'user.notifications': 'false',
#    'user.profile_background_color': '9266CC',
#    'user.profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#    'user.profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#    'user.profile_background_tile': 'true',
#    'user.profile_image_url': 'http://pbs.twimg.com/profile_images/810887357260058624/Zx4EKTR9_normal.jpg',
#    'user.profile_image_url_https': 'https://pbs.twimg.com/profile_images/810887357260058624/Zx4EKTR9_normal.jpg',
#    'user.profile_link_color': '9266CC',
#    'user.profile_sidebar_border_color': 'FFFFFF',
#    'user.profile_sidebar_fill_color': '252429',
#    'user.profile_text_color': '666666',
#    'user.profile_use_background_image': 'false',
#    'user.protected': 'false',
#    'user.screen_name': 'Chris_Garner1',
#    'user.statuses_count': '205375',
#    'user.time_zone': 'null',
#    'user.translator_type': 'none',
#    'user.url': 'null',
#    'user.utc_offset': 'null',
#    'user.verified': 'false'},
#   'score': 0.0,
#   'statisicalData': {'User Followers': 1337.0,
#    'User Follows': 663.0,
#    'User Statuses': 205375.0},
#   'text': 'SPC Tornado Watch 368 Status Reports http://dlvr.it/SzjZv',
#   'timestamp': 1306344370097,
#   'type': 'TWEETS'},
#  {'identifier': '74927384448610304',
#   'lang': 'en',
#   'location': {'description': None,
#    'geolocation': {'latitude': 40.773041, 'longitude': -73.957489},
#    'identifier': None,
#    'name': 'New York (New York County, New York, United States)',
#    'radius': 0.0},
#   'media': [],
#   'metadata': {'content': 'RT @DanaRoecker: Mash unit set up in #Joplin, Mo. #NBCNews http://t.co/a5iKxqO',
#    'contributors': 'null',
#    'coordinates': 'null',
#    'created_at': 'Sun May 29 19:57:35 +0000 2011',
#    'docno': '74927384448610304',
#    'entities.hashtags': '[{"text":"Joplin","indices":[37,44]},{"text":"NBCNews","indices":[50,58]}]',
#    'entities.symbols': '[]',
#    'entities.urls': '[{"expanded_url":"http://yfrog.com/hs7aeykj","indices":[59,78],"display_url":"yfrog.com/hs7aeykj","url":"http://t.co/a5iKxqO"}]',
#    'entities.user_mentions': '[{"id":44698055,"name":"Dana","indices":[3,15],"screen_name":"DanaRoecker","id_str":"44698055"}]',
#    'favorite_count': '1',
#    'favorited': 'false',
#    'geo': 'null',
#    'id': '74927384448610304',
#    'id_str': '74927384448610304',
#    'in_reply_to_screen_name': 'null',
#    'in_reply_to_status_id': 'null',
#    'in_reply_to_status_id_str': 'null',
#    'in_reply_to_user_id': 'null',
#    'in_reply_to_user_id_str': 'null',
#    'is_quote_status': 'false',
#    'label': '???',
#    'lang': 'en',
#    'place': 'null',
#    'possibly_sensitive': 'false',
#    'retweet_count': '9',
#    'retweeted': 'false',
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'srcjson': '{"contributors":null,"text":"RT @DanaRoecker: Mash unit set up in #Joplin, Mo. #NBCNews http://t.co/a5iKxqO","geo":null,"retweeted":false,"in_reply_to_screen_name":null,"possibly_sensitive":false,"truncated":false,"lang":"en","entities":{"symbols":[],"urls":[{"expanded_url":"http://yfrog.com/hs7aeykj","indices":[59,78],"display_url":"yfrog.com/hs7aeykj","url":"http://t.co/a5iKxqO"}],"hashtags":[{"text":"Joplin","indices":[37,44]},{"text":"NBCNews","indices":[50,58]}],"user_mentions":[{"id":44698055,"name":"Dana","indices":[3,15],"screen_name":"DanaRoecker","id_str":"44698055"}]},"in_reply_to_status_id_str":null,"is_quote_status":false,"id":74927384448610304,"source":"<a href=\\"http://twitter.com\\" rel=\\"nofollow\\">Twitter Web Client<\\/a>","in_reply_to_user_id_str":null,"favorited":false,"in_reply_to_status_id":null,"retweet_count":9,"created_at":"Sun May 29 19:57:35 +0000 2011","in_reply_to_user_id":null,"favorite_count":1,"id_str":"74927384448610304","place":null,"user":{"location":"New York, NY","default_profile":false,"profile_background_tile":true,"statuses_count":160798,"lang":"en","profile_link_color":"5172A0","profile_banner_url":"https://pbs.twimg.com/profile_banners/14173315/1531891112","id":14173315,"following":false,"protected":false,"favourites_count":770,"profile_text_color":"000000","description":"The leading source of global news and info for more than 75 years. \\n\\nhttps://t.co/Hd7rJQeDzP","verified":true,"contributors_enabled":false,"profile_sidebar_border_color":"FFFFFF","name":"NBC News","profile_background_color":"062131","created_at":"Tue Mar 18 23:19:17 +0000 2008","is_translation_enabled":false,"default_profile_image":false,"followers_count":6095523,"has_extended_profile":false,"profile_image_url_https":"https://pbs.twimg.com/profile_images/875411730679173121/l9PSFLJb_normal.jpg","geo_enabled":true,"profile_background_image_url":"http://abs.twimg.com/images/themes/theme1/bg.png","profile_background_image_url_https":"https://abs.twimg.com/images/themes/theme1/bg.png","follow_request_sent":false,"entities":{"description":{"urls":[{"expanded_url":"https://www.instagram.com/nbcnews","indices":[69,92],"display_url":"instagram.com/nbcnews","url":"https://t.co/Hd7rJQeDzP"}]},"url":{"urls":[{"expanded_url":"http://NBCNews.com","indices":[0,23],"display_url":"NBCNews.com","url":"https://t.co/Z73is4fJ3x"}]}},"url":"https://t.co/Z73is4fJ3x","utc_offset":null,"time_zone":null,"translator_type":"none","notifications":false,"profile_use_background_image":true,"friends_count":2799,"profile_sidebar_fill_color":"FFFFFF","screen_name":"NBCNews","id_str":"14173315","profile_image_url":"http://pbs.twimg.com/profile_images/875411730679173121/l9PSFLJb_normal.jpg","listed_count":38910,"is_translator":false},"coordinates":null}',
#    'text': 'RT @DanaRoecker: Mash unit set up in #Joplin, Mo. #NBCNews http://t.co/a5iKxqO',
#    'timestamp': '1306695455098',
#    'truncated': 'false',
#    'user.contributors_enabled': 'false',
#    'user.created_at': 'Tue Mar 18 23:19:17 +0000 2008',
#    'user.default_profile': 'false',
#    'user.default_profile_image': 'false',
#    'user.description': 'The leading source of global news and info for more than 75 years. \n\nhttps://t.co/Hd7rJQeDzP',
#    'user.entities.description.urls': '[{"expanded_url":"https://www.instagram.com/nbcnews","indices":[69,92],"display_url":"instagram.com/nbcnews","url":"https://t.co/Hd7rJQeDzP"}]',
#    'user.entities.url.urls': '[{"expanded_url":"http://NBCNews.com","indices":[0,23],"display_url":"NBCNews.com","url":"https://t.co/Z73is4fJ3x"}]',
#    'user.favourites_count': '770',
#    'user.follow_request_sent': 'false',
#    'user.followers_count': '6095523',
#    'user.following': 'false',
#    'user.friends_count': '2799',
#    'user.geo_enabled': 'true',
#    'user.has_extended_profile': 'false',
#    'user.id': '14173315',
#    'user.id_str': '14173315',
#    'user.is_translation_enabled': 'false',
#    'user.is_translator': 'false',
#    'user.lang': 'en',
#    'user.listed_count': '38910',
#    'user.location': 'New York, NY',
#    'user.name': 'NBC News',
#    'user.notifications': 'false',
#    'user.profile_background_color': '062131',
#    'user.profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'user.profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'user.profile_background_tile': 'true',
#    'user.profile_banner_url': 'https://pbs.twimg.com/profile_banners/14173315/1531891112',
#    'user.profile_image_url': 'http://pbs.twimg.com/profile_images/875411730679173121/l9PSFLJb_normal.jpg',
#    'user.profile_image_url_https': 'https://pbs.twimg.com/profile_images/875411730679173121/l9PSFLJb_normal.jpg',
#    'user.profile_link_color': '5172A0',
#    'user.profile_sidebar_border_color': 'FFFFFF',
#    'user.profile_sidebar_fill_color': 'FFFFFF',
#    'user.profile_text_color': '000000',
#    'user.profile_use_background_image': 'true',
#    'user.protected': 'false',
#    'user.screen_name': 'NBCNews',
#    'user.statuses_count': '160798',
#    'user.time_zone': 'null',
#    'user.translator_type': 'none',
#    'user.url': 'https://t.co/Z73is4fJ3x',
#    'user.utc_offset': 'null',
#    'user.verified': 'true'},
#   'score': 0.0,
#   'statisicalData': {'User Followers': 6095523.0,
#    'User Follows': 2799.0,
#    'User Statuses': 160798.0},
#   'text': 'RT @DanaRoecker: Mash unit set up in #Joplin, Mo. #NBCNews http://t.co/a5iKxqO',
#   'timestamp': 1306695455098,
#   'type': 'TWEETS'}]

# %%
tweet_data_frame = pd.DataFrame.from_dict(dat)
tweet_data_frame.set_index('identifier')
# Out:
#                                                                 text  ... media
# identifier                                                            ...
# 74290454534963200  #PrayN4t/Lords  Healing & Restoration N Joplin...  ...    []
# 74920217951744000  RT @Bill_Gross: Amazing - and stunningly sad -...  ...    []
# 77079355364343808  RT @velvetrasputin: The tornado damage in N. M...  ...    []
# 74304399119351808  RT @CrossCzech17: A tornado kills 125 innocent...  ...    []
# 77720662453649408  Death toll from Joplin tornado rises to 141: o...  ...    []
# ...                                                              ...  ...   ...
# 74953616473079808  AP VIDEO: Obama speaks at a memorial service f...  ...    []
# 75889362948198400  RT @nytjim: More side-by-side before & after p...  ...    []
# 75119780213956608  Obama | President | Tornado | Barack | Missour...  ...    []
# 73454830265442304  SPC Tornado Watch 368 Status Reports http://dl...  ...    []
# 74927384448610304  RT @DanaRoecker: Mash unit set up in #Joplin, ...  ...    []
#
# [152 rows x 9 columns]

# %%
from google.colab import files
tweet_data_frame.to_csv('joplinTornado2011.csv')
