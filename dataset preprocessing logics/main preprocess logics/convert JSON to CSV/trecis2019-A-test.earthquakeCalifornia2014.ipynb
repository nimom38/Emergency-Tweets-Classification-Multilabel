# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-004d661b-6d7f-4206-a4c2-56580a7b2fb0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-004d661b-6d7f-4206-a4c2-56580a7b2fb0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving trecis2019-A-test.earthquakeCalifornia2014.json.gz to trecis2019-A-test.earthquakeCalifornia2014.json.gz

# %%
# !gunzip "trecis2019-A-test.earthquakeCalifornia2014.json.gz"

# %%
import pandas as pd
import json

# %%
file_name = "trecis2019-A-test.earthquakeCalifornia2014.json"

dat=list()
with open (file_name, 'r') as f:
    for l in f.readlines():
        if not l.strip (): # skip empty lines
            continue

        json_data = json.loads (l)
        dat.append(json_data)

dat
# Out:
# [{'allProperties': {'content': 'WCVB Boston: California quake: Recovering after 6.0 tremor. http://t.co/9LgBex6FSc',
#    'contributors': 'null',
#    'coordinates': 'null',
#    'created_at': 'Mon Aug 25 11:28:12 +0000 2014',
#    'docno': '503866427322159104',
#    'entities.hashtags': '[]',
#    'entities.symbols': '[]',
#    'entities.urls': '[{"expanded_url":"http://google.com/newsstand/s/CBIwjZjtrR8","indices":[60,82],"display_url":"google.com/newsstand/s/CBâ€¦","url":"http://t.co/9LgBex6FSc"}]',
#    'entities.user_mentions': '[]',
#    'favorite_count': '0',
#    'favorited': 'false',
#    'geo': 'null',
#    'id': '503866427322159104',
#    'id_str': '503866427322159104',
#    'in_reply_to_screen_name': 'null',
#    'in_reply_to_status_id': 'null',
#    'in_reply_to_status_id_str': 'null',
#    'in_reply_to_user_id': 'null',
#    'in_reply_to_user_id_str': 'null',
#    'is_quote_status': 'false',
#    'lang': 'en',
#    'place': 'null',
#    'possibly_sensitive': 'false',
# ...

# %%
for i in range(len(dat)):
  dat[i]['identifier'] = dat[i]['allProperties']['id']
tweet_data_frame = pd.DataFrame.from_dict(dat)
tweet_data_frame.set_index('identifier')
# Out:
#                                                         allProperties  ...                     topic
# identifier                                                             ...
# 503866427322159104  {'user.verified': 'false', 'user.listed_count'...  ...  earthquakeCalifornia2014
# 503866526676819969  {'user.verified': 'false', 'user.listed_count'...  ...  earthquakeCalifornia2014
# 503866635745099776  {'user.verified': 'false', 'user.listed_count'...  ...  earthquakeCalifornia2014
# 503866707568373760  {'user.verified': 'false', 'user.listed_count'...  ...  earthquakeCalifornia2014
# 503866815203012608  {'user.verified': 'false', 'user.listed_count'...  ...  earthquakeCalifornia2014
# ...                                                               ...  ...                       ...
# 504284375115370496  {'user.verified': 'false', 'user.listed_count'...  ...  earthquakeCalifornia2014
# ...

# %%
from google.colab import files
tweet_data_frame.to_csv('trecis2019-A-test.earthquakeCalifornia2014.csv')
