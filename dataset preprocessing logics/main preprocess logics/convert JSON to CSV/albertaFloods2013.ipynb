# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-98e3cf90-cd66-4623-b52a-01efd403d85c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-98e3cf90-cd66-4623-b52a-01efd403d85c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving albertaFloods2013.json to albertaFloods2013.json

# %%
import pandas as pd
import json

# %%
file_name = "albertaFloods2013.json"

dat=list()
with open (file_name, 'r') as f:
    for l in f.readlines():
        if not l.strip (): # skip empty lines
            continue

        json_data = json.loads (l)
        dat.append(json_data)

dat
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
tweet_data_frame = pd.DataFrame.from_dict(dat)
tweet_data_frame.set_index('identifier')
# Out:
#                                                                  text  ...                                              media
# identifier                                                             ...
# 351734622884855808  #yycflood be sure when you are ready for re bu...  ...                                                 []
# 351741648327294977  RT @CansForCalgary: Happy Canada Day everyone!...  ...                                                 []
# 351776825967513600  RT @redcrosscanada: Unloading a truck filled w...  ...  [{'identifier': '351776666315534337', 'url': '...
# 352043285876977664  Unofficial ?anthem? of #Alberta floods by #Can...  ...                                                 []
# 352054501466849280  RT @paulbrandt: Get the Alberta Strong (Flood ...  ...                                                 []
# ...                                                               ...  ...                                                ...
# 350708096320024576  RT @mrlube: We're donating $5 from every oil c...  ...                                                 []
# 350725741777911809  RT @calgarysun: Mayor of High River asks provi...  ...                                                 []
# 350726014369927168  going to the @calstampeders game tonight?? che...  ...                                                 []
# 350726454801215488  RT @bpincott: Christ Church Elbow Park has foo...  ...                                                 []
# 350728832950599680  Don't reach for things blindly under water. Us...  ...                                                 []
#
# [739 rows x 9 columns]

# %%
from google.colab import files
tweet_data_frame.to_csv('albertaFloods2013.csv')
