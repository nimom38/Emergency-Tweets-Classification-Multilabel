# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-13266c80-14de-4ecf-af16-6df41e505f95" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-13266c80-14de-4ecf-af16-6df41e505f95">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving typhoonPablo2012.json to typhoonPablo2012.json

# %%
import pandas as pd
import json

# %%
file_name = "typhoonPablo2012.json"

dat=list()
with open (file_name, 'r') as f:
    for l in f.readlines():
        if not l.strip (): # skip empty lines
            continue

        json_data = json.loads (l)
        dat.append(json_data)

dat
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
tweet_data_frame = pd.DataFrame.from_dict(dat)
tweet_data_frame.set_index('identifier')
# Out:
#                                                                  text  ... media
# identifier                                                             ...
# 274317493407981568  We're tracking Typhoon #Bopha as it heads towa...  ...    []
# 274432077594759169  [NEWS] Typhoon Bopha is forecast to strike the...  ...    []
# 274530656321675264  Wag nmn sana tumuloy ung bagyong c #pablo wag ...  ...    []
# 274660784620052480  #Weather Update: Visayas will be greatly affec...  ...    []
# 274681584194560000  The Watchers - Tropical Storm Bopha upgraded t...  ...    []
# ...                                                               ...  ...   ...
# 279508338897727488  Más de 1.800 muertos y desaparecidos por el #t...  ...    []
# 279511081955766272  KC Concepcion helps the World Food Programme's...  ...    []
# 279578320838983680  RT @ANCALERTS: Canada to give P70M more for ty...  ...    []
# 279603729945227264  RT @ayalamuseum: Read about Ayala Foundation's...  ...    []
# 279622415582109696  RT @WFP: Actress &amp; @WFP advocate @kc_conce...  ...    []
#
# [649 rows x 9 columns]

# %%
from google.colab import files
tweet_data_frame.to_csv('typhoonPablo2012.csv')
