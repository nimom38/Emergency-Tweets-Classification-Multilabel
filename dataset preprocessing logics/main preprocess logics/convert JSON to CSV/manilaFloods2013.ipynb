# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2ff97098-008a-49dd-8281-65feb36ae6fa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2ff97098-008a-49dd-8281-65feb36ae6fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving manilaFloods2013.json to manilaFloods2013.json

# %%
import pandas as pd
import json

# %%
file_name = "manilaFloods2013.json"

dat=list()
with open (file_name, 'r') as f:
    for l in f.readlines():
        if not l.strip (): # skip empty lines
            continue

        json_data = json.loads (l)
        dat.append(json_data)

dat
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
tweet_data_frame = pd.DataFrame.from_dict(dat)
tweet_data_frame.set_index('identifier')
# Out:
#                                                                  text  ... media
# identifier                                                             ...
# 368659239272579073  RT @dost_pagasa: WEATHER BULLETIN No. 2\nTropi...  ...    []
# 368967734542864384  RT @ANCALERTS: PAGASA 12:20pm: YELLOW advisory...  ...    []
# 369087058293186561  RT @ryan_chua: PAGASA raises red rainfall warn...  ...    []
# 369089159635283968  RT @PIAalerts: PAGASA: Red Rainfall Warning No...  ...    []
# 369091105783955458  RT @PhilstarNews: Corrected: CITY OF MANILA ha...  ...    []
# ...                                                               ...  ...   ...
# 371833773752467456  RT @climatehawk1: Adaptation: Most of Manila l...  ...    []
# 371940833362059264  RT @ShutangInaBeks: PUBLIC SERVICE: For rescue...  ...    []
# 372059611882590208  RT @javellanajohn: Monsoon Rains Flood the Phi...  ...    []
# 372131883909668865  "@gmanews:Lea Salonga to perform in fundraiser...  ...    []
# 372310041191141376  All about #MaringPH #NMFChat\n\nEpisode 23 is ...  ...    []
#
# [443 rows x 9 columns]

# %%
from google.colab import files
tweet_data_frame.to_csv('manilaFloods2013.csv')
