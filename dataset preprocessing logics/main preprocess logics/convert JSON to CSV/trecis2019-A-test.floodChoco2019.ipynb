# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-89ff8823-1666-4c01-9e8d-29ce1034b7ab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-89ff8823-1666-4c01-9e8d-29ce1034b7ab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving trecis2019-A-test.floodChoco2019.json.gz to trecis2019-A-test.floodChoco2019.json.gz

# %%
# !gunzip "trecis2019-A-test.floodChoco2019.json.gz"

# %%
import pandas as pd
import json

# %%
file_name = "trecis2019-A-test.floodChoco2019.json"

dat=list()
with open (file_name, 'r') as f:
    for l in f.readlines():
        if not l.strip (): # skip empty lines
            continue

        json_data = json.loads (l)
        dat.append(json_data)

dat
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
for i in range(len(dat)):
  dat[i]['identifier'] = dat[i]['allProperties']['id']
tweet_data_frame = pd.DataFrame.from_dict(dat)
tweet_data_frame.set_index('identifier')
# Out:
#                                                          allProperties  ...           topic
# identifier                                                              ...
# 1099366276177190912  {'user.listed_count': '2', 'retweeted_status.u...  ...  floodChoco2019
# 1099544753262096385  {'user.listed_count': '0', 'user.verified': 'f...  ...  floodChoco2019
# 1099580253905670144  {'user.listed_count': '0', 'user.verified': 'f...  ...  floodChoco2019
# 1099594165946441729  {'user.listed_count': '0', 'user.profile_backg...  ...  floodChoco2019
# 1099617854855335936  {'user.listed_count': '0', 'retweeted_status.u...  ...  floodChoco2019
# ...                                                                ...  ...             ...
# 1103242991513276417  {'user.listed_count': '1', 'user.profile_backg...  ...  floodChoco2019
# 1103243958589636608  {'user.listed_count': '1', 'retweeted_status.u...  ...  floodChoco2019
# ...

# %%
from google.colab import files
tweet_data_frame.to_csv('trecis2019-A-test.floodChoco2019.csv')
