# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6d599d27-84db-42d6-a13a-7dd2c78b637c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6d599d27-84db-42d6-a13a-7dd2c78b637c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 4. TestSet_2019-B.csv to 4. TestSet_2019-B.csv
# Saving 3. TestSet_2019-A.csv to 3. TestSet_2019-A.csv

# %%
import pandas as pd

# %%
ss = [
      '4. TestSet_2019-B.csv',
'3. TestSet_2019-A.csv'
]

frames = []

for i in range(2):
  files = pd.read_csv(ss[i])
  frames.append(files)
  print(files.columns)

result = pd.concat(frames, ignore_index=True)
result.drop(['Unnamed: 0'], axis=1, inplace=True)
#result.set_index('identifier')
# result.set_index('identifier', inplace=True, drop=True)
result
# Out:
# Index(['Unnamed: 0', 'XXXX', 'identifier', 'tweet_text', 'user_verified',
#        'user_followers', 'user_following', 'media', 'user_statuses',
#        'timestamp', 'language', 'location_metadata', 'GoodsServices',
#        'SearchAndRescue', 'InformationWanted', 'Volunteer', 'Donations',
#        'MovePeople', 'FirstPartyObservation', 'ThirdPartyObservation',
#        'Weather', 'EmergingThreats', 'NewSubEvent', 'MultimediaShare',
#        'ServiceAvailable', 'Factoid', 'Official', 'News', 'CleanUp',
#        'Hashtags', 'OriginalEvent', 'ContextualInformation', 'Advice',
#        'Sentiment', 'Discussion', 'Irrelevant', 'Location', 'priority_level'],
#       dtype='object')
# Index(['Unnamed: 0', 'XXXX', 'identifier', 'tweet_text', 'user_verified',
#        'user_followers', 'user_following', 'media', 'user_statuses',
#        'timestamp', 'language', 'location_metadata', 'GoodsServices',
#        'SearchAndRescue', 'InformationWanted', 'Volunteer', 'Donations',
#        'MovePeople', 'FirstPartyObservation', 'ThirdPartyObservation',
#        'Weather', 'EmergingThreats', 'NewSubEvent', 'MultimediaShare',
#        'ServiceAvailable', 'Factoid', 'Official', 'News', 'CleanUp',
#        'Hashtags', 'OriginalEvent', 'ContextualInformation', 'Advice',
#        'Sentiment', 'Discussion', 'Irrelevant', 'Location', 'priority_level'],
#       dtype='object')
#                     XXXX           identifier  ... Location  priority_level
# 0          GoodsServices  1132263689858572288  ...        1            High
# 1          GoodsServices  1131676373771096064  ...        1             Low
# 2          GoodsServices  1134620703532101632  ...        1             Low
# 3          GoodsServices  1133867016513736704  ...        1            High
# 4      InformationWanted  1134851996681351168  ...        1             Low
# ...                  ...                  ...  ...      ...             ...
# 30588           Location   751242389688184832  ...        1             Low
# 30589           Location   751243305891926016  ...        1          Medium
# 30590           Location   751243320345522176  ...        1            High
# 30591           Location   751243408392368128  ...        1          Medium
# 30592           Location   751243799892930560  ...        1            High
#
# [30593 rows x 37 columns]

# %%
from google.colab import files
result.to_csv('2019.csv')
files.download('2019.csv')
