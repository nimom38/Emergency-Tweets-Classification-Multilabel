# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2f4f6c62-a89f-4182-af27-9285789e4cdc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f4f6c62-a89f-4182-af27-9285789e4cdc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving fireColorado2012.json to fireColorado2012.json

# %%
import pandas as pd
import json

# %%
file_name = "fireColorado2012.json"

dat=list()
with open (file_name, 'r') as f:
    for l in f.readlines():
        if not l.strip (): # skip empty lines
            continue

        json_data = json.loads (l)
        dat.append(json_data)

dat
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
tweet_data_frame = pd.DataFrame.from_dict(dat)
tweet_data_frame.set_index('identifier')
# Out:
#                                                                  text  ... media
# identifier                                                             ...
# 211281973870727170  #colorado. Told you its #amazing http://t.co/6...  ...    []
# 211557401231495171  RT @northfortynews: Tanker helicopter heads up...  ...    []
# 211565974422425600  #Evacuation center Cache La Poudre Middle Scho...  ...    []
# 211607187653533697  20F degrees cooler tomorrow in North Central &...  ...    []
# 211654415503990784  FEMA has authorized the use of federal funds t...  ...    []
# ...                                                               ...  ...   ...
# 222035313701302272  Waldo Canyon fire near Colorado Springs reache...  ...    []
# 222044755075416064  Colorado?s Waldo Canyon Fire reaches 98% conta...  ...    []
# 222071430857244672  RT @cnnbrk: Colorado governor lifts statewide ...  ...    []
# 222071921586606080  #SiguemeYTeSigo Colorado governor lifts statew...  ...    []
# 222082147291369472  RT @News1130radio: BC Wildfire Management says...  ...    []
#
# [744 rows x 9 columns]

# %%
from google.colab import files
tweet_data_frame.to_csv('fireColorado2012.csv')
