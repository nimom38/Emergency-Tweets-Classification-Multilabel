# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-295a8a44-e2fa-4ce0-83b7-d290ef57de4a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-295a8a44-e2fa-4ce0-83b7-d290ef57de4a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving parisAttacks2015.json to parisAttacks2015.json

# %%
import pandas as pd
import json

# %%
file_name = "parisAttacks2015.json"

dat=list()
with open (file_name, 'r') as f:
    for l in f.readlines():
        if not l.strip (): # skip empty lines
            continue

        json_data = json.loads (l)
        dat.append(json_data)

dat
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
tweet_data_frame = pd.DataFrame.from_dict(dat)
tweet_data_frame.set_index('identifier')
# Out:
#                                                                  text  ... media
# identifier                                                             ...
# 665290631930060800  RT @cheerio15: Restaurant in Paris 10th distri...  ...    []
# 665308764333961217  public transport problems in paris due to five...  ...    []
# 665308229468073984  RT @AP: BREAKING: French police official confi...  ...    []
# 665365972631420929  At least 3 of the dead attackers at Bataclan t...  ...    []
# 665284063901696002  RT @michaelh992: PT: According to Police Union...  ...    []
# ...                                                               ...  ...   ...
# 665284742686773248  French police report shootout and explosion in...  ...    []
# 665370375438606337  Let's spread love and prayer. #ALDUBHappyBdayL...  ...    []
# 665321905000345600  Extra, Extra: Obama Delivering Statement On Pa...  ...    []
# 665405083442651137  New York, other US cities beef up security aft...  ...    []
# 665289991984160768  ...And then a hostage situation is occurring i...  ...    []
#
# [2066 rows x 9 columns]

# %%
from google.colab import files
tweet_data_frame.to_csv('parisAttacks2015.csv')
