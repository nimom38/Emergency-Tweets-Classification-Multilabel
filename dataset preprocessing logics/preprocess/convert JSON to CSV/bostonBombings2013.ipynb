# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f37a41d0-8b06-4b43-a21b-b1fd4c10bcab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f37a41d0-8b06-4b43-a21b-b1fd4c10bcab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bostonBombings2013.json to bostonBombings2013.json

# %%
import pandas as pd
import json

# %%
file_name = "bostonBombings2013.json"

dat=list()
with open (file_name, 'r') as f:
    for l in f.readlines():
        if not l.strip (): # skip empty lines
            continue

        json_data = json.loads (l)
        dat.append(json_data)

dat
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
tweet_data_frame = pd.DataFrame.from_dict(dat)
tweet_data_frame.set_index('identifier')
# Out:
#                                                                  text  ... media
# identifier                                                             ...
# 327714703675641856  Latest developments in the Boston bombing inve...  ...    []
# 327895134270263296  The Lede: The Tale of the Tsarnaev Brothers? C...  ...    []
# 327913819873607681  RT @irritatedwoman: Rep. King: NYC Should Have...  ...    []
# 328258189021810688  A letter of hope on the marathon bombing - htt...  ...    []
# 328350748922494976  Jihad Discussions Led to Warning on Tamerlan T...  ...    []
# ...                                                               ...  ...   ...
# 337175551951400960  Orlando man killed by FBI had ties to Boston M...  ...    []
# 337359539294842880  Friend of Boston Bombing Suspect Shot and Kill...  ...    []
# 337542079603437569  What's worse- security service saying they kne...  ...    []
# 337825887162617856  Steve Sailer: Tsarnaev-Todashev story has immi...  ...    []
# 337937153688473600  RT @RedSox: #RedSox fans: Help @davidortiz rai...  ...    []
#
# [543 rows x 9 columns]

# %%
from google.colab import files
tweet_data_frame.to_csv('bostonBombings2013.csv')
