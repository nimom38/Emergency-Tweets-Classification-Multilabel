# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f34be06c-f051-4301-a1f7-20b36ab6b379" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f34be06c-f051-4301-a1f7-20b36ab6b379">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving floodColorado2013.json to floodColorado2013.json

# %%
import pandas as pd
import json

# %%
file_name = "floodColorado2013.json"

dat=list()
with open (file_name, 'r') as f:
    for l in f.readlines():
        if not l.strip (): # skip empty lines
            continue

        json_data = json.loads (l)
        dat.append(json_data)

dat
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
tweet_data_frame = pd.DataFrame.from_dict(dat)
tweet_data_frame.set_index('identifier')
# Out:
#                                                                  text  ... media
# identifier                                                             ...
# 378011169883037697  RT @dlfluegge: Crazy Flooding in Boulder, Colo...  ...    []
# 378020179214491649  Here's the #boulderflood video that's circulat...  ...    []
# 378026101588496385  RT @passantino: Video: Severe flooding hits ne...  ...    []
# 378029784204206080  Crazy Flooding in Boulder, Colorado http://t.c...  ...    []
# 378038458024865792  Thoughts and prayers out to those in Boulder w...  ...    []
# ...                                                               ...  ...   ...
# 384690443801202688  RT @KyleDyer9News: #Boulder estimates $49M in ...  ...    []
# 384696248709562369  I am grateful for the support of the House - t...  ...    []
# 384720810575138817  Impact of government shutdown on federal flood...  ...    []
# 384840239178465280  Nice republicans @denverpost: #CoFlood: Colora...  ...    []
# 384913589158420480  RT @coloradoan: Shutdown could slow flood reco...  ...    []
#
# [777 rows x 9 columns]

# %%
from google.colab import files
tweet_data_frame.to_csv('floodColorado2013.csv')
