# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7bf703eb-f6d9-4860-9c6e-09f5260d4cb8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7bf703eb-f6d9-4860-9c6e-09f5260d4cb8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving flSchoolShooting2018.json to flSchoolShooting2018.json

# %%
import pandas as pd
import json

# %%
file_name = "flSchoolShooting2018.json"

dat=list()
with open (file_name, 'r') as f:
    for l in f.readlines():
        if not l.strip (): # skip empty lines
            continue

        json_data = json.loads (l)
        dat.append(json_data)

dat
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
tweet_data_frame = pd.DataFrame.from_dict(dat)
tweet_data_frame.set_index('identifier')
# Out:
#                                                                  text  ... media
# identifier                                                             ...
# 966843468713746432  #ITMFA Manafort and Gates @jpw643 US Women End...  ...    []
# 966742939274801152  RT @american_jonny: Anthony Borges, 15 years o...  ...    []
# 966665193160835073  RT @WangCecillia: Another teenaged hero in the...  ...    []
# 966620813700018177  #ITMFA @jpw643 US Women #ParklandStudentsSpeak...  ...    []
# 966135462372040704  #ITMFA @jpw643 #ParklandStrong #GunControlNow ...  ...    []
# ...                                                               ...  ...   ...
# 965966411368685568  RT @UniNoticias: Los estudiantes de Parkland l...  ...    []
# 965901097390002176  @ocs_tecnologia  Hi, Thanks for your Like Of "...  ...    []
# 964205803828862977  RT @weartv: #UPDATE: #FloridaSchoolShooting su...  ...    []
# 963854880921309187  Have you toured a city on a college campus on ...  ...    []
# 963561479172710402  Next up, we got my guy lil fool, my mans will ...  ...    []
#
# [1118 rows x 9 columns]

# %%
from google.colab import files
tweet_data_frame.to_csv('flSchoolShooting2018.csv')
