# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9ade087a-bb62-4114-8014-7fc9e59436ab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9ade087a-bb62-4114-8014-7fc9e59436ab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving queenslandFloods2013.json to queenslandFloods2013.json

# %%
import pandas as pd
import json

# %%
file_name = "queenslandFloods2013.json"

dat=list()
with open (file_name, 'r') as f:
    for l in f.readlines():
        if not l.strip (): # skip empty lines
            continue

        json_data = json.loads (l)
        dat.append(json_data)

dat
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
tweet_data_frame = pd.DataFrame.from_dict(dat)
tweet_data_frame.set_index('identifier')
# Out:
#                                                                  text  ...                                              media
# identifier                                                             ...
# 297239100556193792  @tennewsqld #bigwet #bundaberg how awful for t...  ...                                                 []
# 297242577613250561  RT @QPSmedia: #bigwet Latest BoM flood summary...  ...                                                 []
# 297254644625838080  Wisma Putra Malaysian victim of Queensland flo...  ...                                                 []
# 297276920578584576  Hello #world #Happy #Friday #everyone And #wis...  ...                                                 []
# 297299506888835075  Wow that storm hit quickly and packed a punch!...  ...                                                 []
# ...                                                               ...  ...                                                ...
# 297150625890832387  What The? Friday - This week, another good rea...  ...  [{'identifier': '297150625899220992', 'url': '...
# 297151141790244865  RT @QPSmedia: What The? Friday - This week, an...  ...                                                 []
# 297159652037251072  RT @QPSmedia: What The? Friday - This week, an...  ...                                                 []
# 297195249099481088  RT @CaitlynGribbin: #bundaberg #bigwet victims...  ...                                                 []
# 297231802454646784  01/16:16 EST Flood Warning Summary (QLD)  http...  ...                                                 []
#
# [744 rows x 9 columns]

# %%
from google.colab import files
tweet_data_frame.to_csv('queenslandFloods2013.csv')
