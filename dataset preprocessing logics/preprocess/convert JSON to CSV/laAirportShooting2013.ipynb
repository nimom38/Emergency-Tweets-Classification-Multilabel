# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4720f3d9-87cb-4915-a3bd-2cdb8d5e3398" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4720f3d9-87cb-4915-a3bd-2cdb8d5e3398">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving laAirportShooting2013.json to laAirportShooting2013.json

# %%
import pandas as pd
import json

# %%
file_name = "laAirportShooting2013.json"

dat=list()
with open (file_name, 'r') as f:
    for l in f.readlines():
        if not l.strip (): # skip empty lines
            continue

        json_data = json.loads (l)
        dat.append(json_data)

dat
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
tweet_data_frame = pd.DataFrame.from_dict(dat)
tweet_data_frame.set_index('identifier')
# Out:
#                                                                  text  ... media
# identifier                                                             ...
# 396263979762196480  KING D ROYALTY http://t.co/2RJIrrnlOi ? #LA #L...  ...    []
# 396313082466541568    Something's happening @ #LAX rt now!! Re-tweet.  ...    []
# 396314030383443968  What the hell is going on at LAX, and why does...  ...    []
# 396315108311199744  Gunshots outside #LAX. Unknown if anyone is in...  ...    []
# 396315620050223104  RT @anblanx: Breaking Shooting at LAX. Termina...  ...    []
# ...                                                               ...  ...   ...
# 398983142846914560  KING D ROYALTY http://t.co/eXjB4V0rbx ? #LA #L...  ...    []
# 399334185133170688  How Los Angeles Airport Turned to Twitter Duri...  ...    []
# 399598535336665088  RT @railgirl1952: LOL they are a JOKE! SoPover...  ...    []
# 399767217648050176  LAX shooting: Latest on suspect, victims and w...  ...    []
# 400397382468505600  LAX shooting suspect upgraded to fair conditio...  ...    []
#
# [683 rows x 9 columns]

# %%
from google.colab import files
tweet_data_frame.to_csv('laAirportShooting2013.csv')
