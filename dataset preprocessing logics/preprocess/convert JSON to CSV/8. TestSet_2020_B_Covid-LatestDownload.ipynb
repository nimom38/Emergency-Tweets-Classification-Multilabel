# %%
import json
from google.colab import files
#uploaded = files.upload()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !gunzip "/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-067.json.gz"
# !gunzip "/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-068.json.gz"
# !gunzip "/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-069.json.gz"
# !gunzip "/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-070.json.gz"
# !gunzip "/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-071.json.gz"
# !gunzip "/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-072.json.gz"
# !gunzip "/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-073.json.gz"
# !gunzip "/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-074.json.gz"
# !gunzip "/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-075.json.gz"

# %%
import pandas as pd
import json

# %%
ss = [
  "/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-067.json",
"/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-068.json",
"/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-069.json",
"/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-070.json",
"/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-071.json",
"/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-072.json",
"/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-073.json",
"/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-074.json",
"/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-075.json"
]
tt = [
  "/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-067.csv",
"/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-068.csv",
"/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-069.csv",
"/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-070.csv",
"/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-071.csv",
"/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-072.csv",
"/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-073.csv",
"/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-074.csv",
"/content/drive/MyDrive/Colab-Notebooks/preprocess/CSV/8. TestSet_2020_B_Covid-LatestDownload/TRECIS-CTIT-H-075.csv"
]

# %%
for i in range(9):
  file_name = ss[i]

  dat=list()
  cc = 0
  with open (file_name, 'r') as f:
      for l in f.readlines():
          if not l.strip (): # skip empty lines
              continue

          json_data = json.loads (l)
          dat.append(json_data)
          cc += 1
          if cc > 500:
            break

  for j in range(len(dat)):
    dat[j]['identifier'] = dat[j]['id_str']
  tweet_data_frame = pd.DataFrame.from_dict(dat)
  tweet_data_frame.set_index('identifier')

  tweet_data_frame.to_csv(tt[i])
  files.download(tt[i])
