# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-46ef3b0d-bbc2-452d-8d42-1e788e468627" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-46ef3b0d-bbc2-452d-8d42-1e788e468627">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving philipinnesFloods2012.json to philipinnesFloods2012.json

# %%
import pandas as pd
import json

# %%
file_name = "philipinnesFloods2012.json"

dat=list()
with open (file_name, 'r') as f:
    for l in f.readlines():
        if not l.strip (): # skip empty lines
            continue

        json_data = json.loads (l)
        dat.append(json_data)

dat
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
tweet_data_frame = pd.DataFrame.from_dict(dat)
tweet_data_frame.set_index('identifier')
# Out:
#                                                                  text  ... media
# identifier                                                             ...
# 230634706436227073  Philippine floods worsen as death toll hits 14...  ...    []
# 230882841498628096  Philippine flood fatalities hit 23 http://t.co...  ...    []
# 232034974851805187  4 Luzon dams release water; flood warning up: ...  ...    []
# 232098107490439169  RT @ANCALERTS: PAGASA 8:50pm advisory: Yellow ...  ...    []
# 232098296242524162  RT @ANCALERTS: PAGASA 8:50pm advisory: Yellow ...  ...    []
# ...                                                               ...  ...   ...
# 234948774613635073  "We need more goods, volunteers" - #ReliefPH o...  ...    []
# 235201250751311875  RT @PawLetsUK: Man during  floods in Manila mo...  ...    []
# 235364799238782976  RT @ANCALERTS: PAGASA 9pm advisory: YELLOW war...  ...    []
# 235382264312246273  Seeds of hope amidst Philippine floods: Rice t...  ...    []
# 235578067018452992  RT @ANCALERTS: PAGASA 11:10am advisory: YELLOW...  ...    []
#
# [480 rows x 9 columns]

# %%
from google.colab import files
tweet_data_frame.to_csv('philipinnesFloods2012.csv')
