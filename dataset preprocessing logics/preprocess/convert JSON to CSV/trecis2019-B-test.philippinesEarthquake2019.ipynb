# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9f36575a-0d94-4c00-b661-2e950d1b7435" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9f36575a-0d94-4c00-b661-2e950d1b7435">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving trecis2019-B-test.philippinesEarthquake2019.json.gz to trecis2019-B-test.philippinesEarthquake2019.json.gz

# %%
# !gunzip "trecis2019-B-test.philippinesEarthquake2019.json.gz"

# %%
import pandas as pd
import json

# %%
file_name = "trecis2019-B-test.philippinesEarthquake2019.json"

dat=list()
with open (file_name, 'r') as f:
    for l in f.readlines():
        if not l.strip (): # skip empty lines
            continue

        json_data = json.loads (l)
        dat.append(json_data)

dat
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
for i in range(len(dat)):
  dat[i]['identifier'] = dat[i]['allProperties']['id']
tweet_data_frame = pd.DataFrame.from_dict(dat)
tweet_data_frame.set_index('identifier')
# Out:
#                                                          allProperties  ...                      topic
# identifier                                                              ...
# 1121930607242518528  {'user.listed_count': '2', 'user.verified': 'f...  ...  philippinesEarthquake2019
# 1120321590170832902  {'user.listed_count': '2', 'user.verified': 'f...  ...  philippinesEarthquake2019
# 1120759261787648001  {'user.listed_count': '5', 'user.verified': 'f...  ...  philippinesEarthquake2019
# 1120622086613942272  {'user.listed_count': '20559', 'user.verified'...  ...  philippinesEarthquake2019
# 1120671467920920576  {'user.listed_count': '23', 'user.verified': '...  ...  philippinesEarthquake2019
# ...                                                                ...  ...                        ...
# 1120478037374578689  {'user.listed_count': '1', 'user.verified': 'f...  ...  philippinesEarthquake2019
# ...

# %%
from google.colab import files
tweet_data_frame.to_csv('trecis2019-B-test.philippinesEarthquake2019.csv')
