# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ad612389-90c1-49c9-8fcd-3f8886a7cb29" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ad612389-90c1-49c9-8fcd-3f8886a7cb29">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving australiaBushfire2013.json to australiaBushfire2013.json

# %%
import pandas as pd
import json

# %%
file_name = "australiaBushfire2013.json"

dat=list()
with open (file_name, 'r') as f:
    for l in f.readlines():
        if not l.strip (): # skip empty lines
            continue

        json_data = json.loads (l)
        dat.append(json_data)

dat
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
tweet_data_frame = pd.DataFrame.from_dict(dat)
tweet_data_frame.set_index('identifier')
# Out:
#                                                                  text  ...                                              media
# identifier                                                             ...
# 395860881978179585  RT @TheEllenShow: Australia's 1 of the most be...  ...                                                 []
# 395910924227596288  RT @nswfire: #nswfires October 2013 sourced in...  ...                                                 []
# 396108375261712385  NSW Fire and Rescue have responded to an indus...  ...                                                 []
# 396227879375089664  We have a number of RAFT members at fires on t...  ...                                                 []
# 388929052247347200  A Total Fire Ban has been declared for the Gre...  ...                                                 []
# ...                                                               ...  ...                                                ...
# 395097472517042176  RT @purplelandia310: Fighting NSW Fires with T...  ...                                                 []
# 395106582540742656  @Fridayology the rain has completely brown pas...  ...                                                 []
# 395336145174675456  RT @702sydney: Image of @LindaMottram w/ Gener...  ...                                                 []
# 395430340866498560  Congratulations to the @NSWWaratahs on raising...  ...  [{'identifier': '395430340874887168', 'url': '...
# 395654908101132288  Other examples of early.@twitterau search fetc...  ...                                                 []
#
# [710 rows x 9 columns]

# %%
from google.colab import files
tweet_data_frame.to_csv('australiaBushfire2013.csv')
