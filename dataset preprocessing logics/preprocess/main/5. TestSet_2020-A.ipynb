# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7a27da50-1191-4628-a170-ae92b012c612" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7a27da50-1191-4628-a170-ae92b012c612">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving trecis2020-A-test.whaleyBridgeCollapse2019.csv to trecis2020-A-test.whaleyBridgeCollapse2019.csv
# Saving trecis2020-A-test.gilroygarlicShooting2019.csv to trecis2020-A-test.gilroygarlicShooting2019.csv
# Saving trecis2020-A-test.typhoonLekima2019.csv to trecis2020-A-test.typhoonLekima2019.csv
# Saving trecis2020-A-test.keralaFloods2019.csv to trecis2020-A-test.keralaFloods2019.csv
# Saving trecis2020-A-test.athensEarthquake2019.csv to trecis2020-A-test.athensEarthquake2019.csv
# Saving trecis2020-A-test.baltimoreFlashFlood2019.csv to trecis2020-A-test.baltimoreFlashFlood2019.csv
# Saving trecis2020-A-test.hurricaneBarry2019.csv to trecis2020-A-test.hurricaneBarry2019.csv
# Saving trecis2020-A-test.daytonOhioShooting2019.csv to trecis2020-A-test.daytonOhioShooting2019.csv
# Saving trecis2020-A-test.elPasoWalmartShooting2019.csv to trecis2020-A-test.elPasoWalmartShooting2019.csv
# Saving trecis2020-A-test.indonesiaEarthquake2019.csv to trecis2020-A-test.indonesiaEarthquake2019.csv
# Saving trecis2020-A-test.myanmarFloods2019.csv to trecis2020-A-test.myanmarFloods2019.csv
# Saving trecis2020-A-test.brooklynBlockPartyShooting2019.csv to trecis2020-A-test.brooklynBlockPartyShooting2019.csv
# Saving trecis2020-A-test.siberianWildfires2019.csv to trecis2020-A-test.siberianWildfires2019.csv
# Saving trecis2020-A-test.typhoonKrosa2019.csv to trecis2020-A-test.typhoonKrosa2019.csv
# Saving trecis2020-A-test.papuaNewguineaEarthquake2019.csv to trecis2020-A-test.papuaNewguineaEarthquake2019.csv

# %%
import json
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3c2752ca-1c45-4a24-bc68-c89cc65f78f4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c2752ca-1c45-4a24-bc68-c89cc65f78f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Combined labels.csv to Combined labels.csv

# %%
import pandas as pd

# %%
clss = [
        "GoodsServices",
"SearchAndRescue",
"InformationWanted",
"Volunteer",
"Donations",
"MovePeople",
"FirstPartyObservation",
"ThirdPartyObservation",
"Weather",
"EmergingThreats",
"NewSubEvent",
"MultimediaShare",
"ServiceAvailable",
"Factoid",
"Official",
"News",
"CleanUp",
"Hashtags",
"OriginalEvent",
"ContextualInformation",
"Advice",
"Sentiment",
"Discussion",
"Irrelevant",
"Location"
]

# %%
def func(a, b):
  for index, value in a.items():
    huhu = value
    if str(int(huhu)) == str(int(b)):
     # print(huhu, b)
      return True
  return False

# %%
def func2(a, b):
  for index, value in a.items():
    huhu = value
    if str(int(huhu)) == str(int(b)):
      return index

# %%
def check(a):
  a = str(a)
  for ch in a:
    if ch >= '0' and ch <= '9':
      continue
    if ch == '.':
      continue
    return False
  return True

# %%
import json
import math
import numpy
cc = 0
combo = pd.read_csv('Combined labels.csv')
print(combo.columns)
hoho = combo['postID']
store = []
file_names = [
              'trecis2020-A-test.whaleyBridgeCollapse2019.csv',
              'trecis2020-A-test.gilroygarlicShooting2019.csv',
              'trecis2020-A-test.typhoonLekima2019.csv',
              'trecis2020-A-test.keralaFloods2019.csv',
              'trecis2020-A-test.athensEarthquake2019.csv',
              'trecis2020-A-test.baltimoreFlashFlood2019.csv',
              'trecis2020-A-test.hurricaneBarry2019.csv',
              'trecis2020-A-test.daytonOhioShooting2019.csv',
              'trecis2020-A-test.elPasoWalmartShooting2019.csv',
              'trecis2020-A-test.indonesiaEarthquake2019.csv',
              'trecis2020-A-test.myanmarFloods2019.csv',
              'trecis2020-A-test.brooklynBlockPartyShooting2019.csv',
              'trecis2020-A-test.siberianWildfires2019.csv',
              'trecis2020-A-test.typhoonKrosa2019.csv',
              'trecis2020-A-test.papuaNewguineaEarthquake2019.csv'
]
assert len(file_names) == 15
# Out:
# Index(['postID', 'eventID', 'eventName', 'eventDescription', 'eventType',
#        'postCategories', 'postPriority'],
#       dtype='object')

# %%
for file in file_names:
  df = pd.read_csv(file)
  for row in df.itertuples(name=None):
    print(row)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
store.clear()
cc = 0
for file in file_names:
  cc += 1
  df = pd.read_csv(file)
  arr = []
  for row in df.itertuples(name=None):
    if (row[6] is None) or ((not isinstance(row[6], str)) and (math.isnan(row[6]) == True)):
      continue
    if (row[6] == "TWEETS"):
      continue
    if check(row[6]) == False:
      continue
    if func(hoho, row[6]) == False:
      continue
    yap = func2(hoho, row[6])
    xxx = None
    if (row[2] is not None) and (isinstance(row[2], str)):
      xxx = eval(row[2])
    dic = {}
    dic['tweet_text'] = None
    if xxx is not None:
      assert 'text' in xxx
      dic['tweet_text'] = xxx['text']
    dic['user_verified'] = None
    if xxx is not None:
      if 'user.verified' in xxx:
        dic['user_verified'] = int(xxx['user.verified']=='true')
    dic['user_followers'] = None
    if xxx is not None:
      if 'user.followersCount' in xxx:
        dic['user_followers'] = int(xxx['user.followersCount'])
      if 'user.followers_count' in xxx:
        dic['user_followers'] = int(xxx['user.followers_count'])
    dic['user_following'] = None
    dic['media'] = 0
    if xxx is not None:
      if 'mediaEntities' in xxx:
        dic['media'] = int(len(xxx['mediaEntities'])>2)
      if 'entities.media' in xxx:
        dic['media'] = int(len(xxx['entities.media'])>2)
      if 'retweeted_status.extended_entities.media' in xxx:
        dic['media'] = int(len(xxx['retweeted_status.extended_entities.media'])>2)
    dic['user_statuses'] = None
    if xxx is not None:
      if 'user.statusesCount' in xxx:
        dic['user_statuses'] = int(xxx['user.statusesCount'])
      if 'user.statuses_count' in xxx:
        dic['user_statuses'] = int(xxx['user.statuses_count'])
    dic['timestamp'] = None
    if xxx is not None:
      if 'timestamp' in xxx:
        dic['timestamp'] = xxx['timestamp']
    dic['identifier'] = str(row[6])
    dic['language'] = None
    if xxx is not None:
      if 'user.lang' in xxx:
        dic['language'] = xxx['user.lang']
    dic['location_metadata'] = None
    if xxx is not None:
      if 'place.boundingBoxCoordinates' in xxx:
        dic['location_metadata'] = xxx['place.boundingBoxCoordinates']
    for words in clss:
      dic[words] = 0
    hmm = int(row[6])
    temp = []
    temp = combo.iloc[yap, 5]
    temp2 = ""
    for i in range(len(temp)):
      if (temp[i] == '[') or (temp[i] == ']') or (temp[i] == ',') or (temp[i] == '\''):
        temp2 += ' '
      else:
        temp2 += temp[i]
    temp2 = list(temp2.split())
    for words in temp2:
      dic[words] = 1
    dic['priority_level'] = combo.iloc[yap, 6]
    arr.append(dic)
  df = pd.DataFrame.from_dict(arr)
  df.drop_duplicates(subset=['identifier'], keep = "first")
  df.set_index('identifier', inplace=True, drop=True)
  store.append(df)
  print(cc, file)
  print(df.shape)
  print(df.columns)
  print(df.info())
  #df.to_csv(file)
  #files.download(file)
# Out:
# 1 trecis2020-A-test.whaleyBridgeCollapse2019.csv
# (107, 35)
# Index(['tweet_text', 'user_verified', 'user_followers', 'user_following',
#        'media', 'user_statuses', 'timestamp', 'language', 'location_metadata',
#        'GoodsServices', 'SearchAndRescue', 'InformationWanted', 'Volunteer',
#        'Donations', 'MovePeople', 'FirstPartyObservation',
#        'ThirdPartyObservation', 'Weather', 'EmergingThreats', 'NewSubEvent',
#        'MultimediaShare', 'ServiceAvailable', 'Factoid', 'Official', 'News',
#        'CleanUp', 'Hashtags', 'OriginalEvent', 'ContextualInformation',
#        'Advice', 'Sentiment', 'Discussion', 'Irrelevant', 'Location',
#        'priority_level'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 107 entries, 1154752023285231616 to 1155652790951145472
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_text             107 non-null    object
#  1   user_verified          107 non-null    int64
#  2   user_followers         107 non-null    int64
#  3   user_following         0 non-null      object
#  4   media                  107 non-null    int64
#  5   user_statuses          107 non-null    int64
#  6   timestamp              107 non-null    object
#  7   language               107 non-null    object
#  8   location_metadata      0 non-null      object
#  9   GoodsServices          107 non-null    int64
#  10  SearchAndRescue        107 non-null    int64
#  11  InformationWanted      107 non-null    int64
#  12  Volunteer              107 non-null    int64
#  13  Donations              107 non-null    int64
#  14  MovePeople             107 non-null    int64
#  15  FirstPartyObservation  107 non-null    int64
#  16  ThirdPartyObservation  107 non-null    int64
#  17  Weather                107 non-null    int64
#  18  EmergingThreats        107 non-null    int64
#  19  NewSubEvent            107 non-null    int64
#  20  MultimediaShare        107 non-null    int64
#  21  ServiceAvailable       107 non-null    int64
#  22  Factoid                107 non-null    int64
#  23  Official               107 non-null    int64
#  24  News                   107 non-null    int64
#  25  CleanUp                107 non-null    int64
#  26  Hashtags               107 non-null    int64
#  27  OriginalEvent          107 non-null    int64
#  28  ContextualInformation  107 non-null    int64
#  29  Advice                 107 non-null    int64
#  30  Sentiment              107 non-null    int64
#  31  Discussion             107 non-null    int64
#  32  Irrelevant             107 non-null    int64
#  33  Location               107 non-null    int64
#  34  priority_level         107 non-null    object
# dtypes: int64(29), object(6)
# memory usage: 30.1+ KB
# None
# 2 trecis2020-A-test.gilroygarlicShooting2019.csv
# (286, 35)
# Index(['tweet_text', 'user_verified', 'user_followers', 'user_following',
#        'media', 'user_statuses', 'timestamp', 'language', 'location_metadata',
#        'GoodsServices', 'SearchAndRescue', 'InformationWanted', 'Volunteer',
#        'Donations', 'MovePeople', 'FirstPartyObservation',
#        'ThirdPartyObservation', 'Weather', 'EmergingThreats', 'NewSubEvent',
#        'MultimediaShare', 'ServiceAvailable', 'Factoid', 'Official', 'News',
#        'CleanUp', 'Hashtags', 'OriginalEvent', 'ContextualInformation',
#        'Advice', 'Sentiment', 'Discussion', 'Irrelevant', 'Location',
#        'priority_level'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 286 entries, 1155878317154852864 to 1155854599221329920
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_text             286 non-null    object
#  1   user_verified          286 non-null    int64
#  2   user_followers         286 non-null    int64
#  3   user_following         0 non-null      object
#  4   media                  286 non-null    int64
#  5   user_statuses          286 non-null    int64
#  6   timestamp              286 non-null    object
#  7   language               286 non-null    object
#  8   location_metadata      0 non-null      object
#  9   GoodsServices          286 non-null    int64
#  10  SearchAndRescue        286 non-null    int64
#  11  InformationWanted      286 non-null    int64
#  12  Volunteer              286 non-null    int64
#  13  Donations              286 non-null    int64
#  14  MovePeople             286 non-null    int64
#  15  FirstPartyObservation  286 non-null    int64
#  16  ThirdPartyObservation  286 non-null    int64
#  17  Weather                286 non-null    int64
#  18  EmergingThreats        286 non-null    int64
#  19  NewSubEvent            286 non-null    int64
#  20  MultimediaShare        286 non-null    int64
#  21  ServiceAvailable       286 non-null    int64
#  22  Factoid                286 non-null    int64
#  23  Official               286 non-null    int64
#  24  News                   286 non-null    int64
#  25  CleanUp                286 non-null    int64
#  26  Hashtags               286 non-null    int64
#  27  OriginalEvent          286 non-null    int64
#  28  ContextualInformation  286 non-null    int64
#  29  Advice                 286 non-null    int64
#  30  Sentiment              286 non-null    int64
#  31  Discussion             286 non-null    int64
#  32  Irrelevant             286 non-null    int64
#  33  Location               286 non-null    int64
#  34  priority_level         286 non-null    object
# dtypes: int64(29), object(6)
# memory usage: 80.4+ KB
# None
# 3 trecis2020-A-test.typhoonLekima2019.csv
# (283, 35)
# Index(['tweet_text', 'user_verified', 'user_followers', 'user_following',
#        'media', 'user_statuses', 'timestamp', 'language', 'location_metadata',
#        'GoodsServices', 'SearchAndRescue', 'InformationWanted', 'Volunteer',
#        'Donations', 'MovePeople', 'FirstPartyObservation',
#        'ThirdPartyObservation', 'Weather', 'EmergingThreats', 'NewSubEvent',
#        'MultimediaShare', 'ServiceAvailable', 'Factoid', 'Official', 'News',
#        'CleanUp', 'Hashtags', 'OriginalEvent', 'ContextualInformation',
#        'Advice', 'Sentiment', 'Discussion', 'Irrelevant', 'Location',
#        'priority_level'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 283 entries, 1160694430791155712 to 1158561380930412544
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_text             283 non-null    object
#  1   user_verified          283 non-null    int64
#  2   user_followers         283 non-null    int64
#  3   user_following         0 non-null      object
#  4   media                  283 non-null    int64
#  5   user_statuses          283 non-null    int64
#  6   timestamp              283 non-null    object
#  7   language               283 non-null    object
#  8   location_metadata      0 non-null      object
#  9   GoodsServices          283 non-null    int64
#  10  SearchAndRescue        283 non-null    int64
#  11  InformationWanted      283 non-null    int64
#  12  Volunteer              283 non-null    int64
#  13  Donations              283 non-null    int64
#  14  MovePeople             283 non-null    int64
#  15  FirstPartyObservation  283 non-null    int64
#  16  ThirdPartyObservation  283 non-null    int64
#  17  Weather                283 non-null    int64
#  18  EmergingThreats        283 non-null    int64
#  19  NewSubEvent            283 non-null    int64
#  20  MultimediaShare        283 non-null    int64
#  21  ServiceAvailable       283 non-null    int64
#  22  Factoid                283 non-null    int64
#  23  Official               283 non-null    int64
#  24  News                   283 non-null    int64
#  25  CleanUp                283 non-null    int64
#  26  Hashtags               283 non-null    int64
#  27  OriginalEvent          283 non-null    int64
#  28  ContextualInformation  283 non-null    int64
#  29  Advice                 283 non-null    int64
#  30  Sentiment              283 non-null    int64
#  31  Discussion             283 non-null    int64
#  32  Irrelevant             283 non-null    int64
#  33  Location               283 non-null    int64
#  34  priority_level         283 non-null    object
# dtypes: int64(29), object(6)
# memory usage: 79.6+ KB
# None
# 4 trecis2020-A-test.keralaFloods2019.csv
# (323, 35)
# Index(['tweet_text', 'user_verified', 'user_followers', 'user_following',
#        'media', 'user_statuses', 'timestamp', 'language', 'location_metadata',
#        'GoodsServices', 'SearchAndRescue', 'InformationWanted', 'Volunteer',
#        'Donations', 'MovePeople', 'FirstPartyObservation',
#        'ThirdPartyObservation', 'Weather', 'EmergingThreats', 'NewSubEvent',
#        'MultimediaShare', 'ServiceAvailable', 'Factoid', 'Official', 'News',
#        'CleanUp', 'Hashtags', 'OriginalEvent', 'ContextualInformation',
#        'Advice', 'Sentiment', 'Discussion', 'Irrelevant', 'Location',
#        'priority_level'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 323 entries, 1160871765528043520 to 1159363499299987456
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_text             323 non-null    object
#  1   user_verified          323 non-null    int64
#  2   user_followers         323 non-null    int64
#  3   user_following         0 non-null      object
#  4   media                  323 non-null    int64
#  5   user_statuses          323 non-null    int64
#  6   timestamp              323 non-null    object
#  7   language               323 non-null    object
#  8   location_metadata      0 non-null      object
#  9   GoodsServices          323 non-null    int64
#  10  SearchAndRescue        323 non-null    int64
#  11  InformationWanted      323 non-null    int64
#  12  Volunteer              323 non-null    int64
#  13  Donations              323 non-null    int64
#  14  MovePeople             323 non-null    int64
#  15  FirstPartyObservation  323 non-null    int64
#  16  ThirdPartyObservation  323 non-null    int64
#  17  Weather                323 non-null    int64
#  18  EmergingThreats        323 non-null    int64
#  19  NewSubEvent            323 non-null    int64
#  20  MultimediaShare        323 non-null    int64
#  21  ServiceAvailable       323 non-null    int64
#  22  Factoid                323 non-null    int64
#  23  Official               323 non-null    int64
#  24  News                   323 non-null    int64
#  25  CleanUp                323 non-null    int64
#  26  Hashtags               323 non-null    int64
#  27  OriginalEvent          323 non-null    int64
#  28  ContextualInformation  323 non-null    int64
#  29  Advice                 323 non-null    int64
#  30  Sentiment              323 non-null    int64
#  31  Discussion             323 non-null    int64
#  32  Irrelevant             323 non-null    int64
#  33  Location               323 non-null    int64
#  34  priority_level         323 non-null    object
# dtypes: int64(29), object(6)
# memory usage: 90.8+ KB
# None
# 5 trecis2020-A-test.athensEarthquake2019.csv
# (276, 35)
# Index(['tweet_text', 'user_verified', 'user_followers', 'user_following',
#        'media', 'user_statuses', 'timestamp', 'language', 'location_metadata',
#        'GoodsServices', 'SearchAndRescue', 'InformationWanted', 'Volunteer',
#        'Donations', 'MovePeople', 'FirstPartyObservation',
#        'ThirdPartyObservation', 'Weather', 'EmergingThreats', 'NewSubEvent',
#        'MultimediaShare', 'ServiceAvailable', 'Factoid', 'Official', 'News',
#        'CleanUp', 'Hashtags', 'OriginalEvent', 'ContextualInformation',
#        'Advice', 'Sentiment', 'Discussion', 'Irrelevant', 'Location',
#        'priority_level'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 276 entries, 1152243083037290496 to 1152181592972025856
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_text             276 non-null    object
#  1   user_verified          276 non-null    int64
#  2   user_followers         276 non-null    int64
#  3   user_following         0 non-null      object
#  4   media                  276 non-null    int64
#  5   user_statuses          276 non-null    int64
#  6   timestamp              276 non-null    object
#  7   language               276 non-null    object
#  8   location_metadata      0 non-null      object
#  9   GoodsServices          276 non-null    int64
#  10  SearchAndRescue        276 non-null    int64
#  11  InformationWanted      276 non-null    int64
#  12  Volunteer              276 non-null    int64
#  13  Donations              276 non-null    int64
#  14  MovePeople             276 non-null    int64
#  15  FirstPartyObservation  276 non-null    int64
#  16  ThirdPartyObservation  276 non-null    int64
#  17  Weather                276 non-null    int64
#  18  EmergingThreats        276 non-null    int64
#  19  NewSubEvent            276 non-null    int64
#  20  MultimediaShare        276 non-null    int64
#  21  ServiceAvailable       276 non-null    int64
#  22  Factoid                276 non-null    int64
#  23  Official               276 non-null    int64
#  24  News                   276 non-null    int64
#  25  CleanUp                276 non-null    int64
#  26  Hashtags               276 non-null    int64
#  27  OriginalEvent          276 non-null    int64
#  28  ContextualInformation  276 non-null    int64
#  29  Advice                 276 non-null    int64
#  30  Sentiment              276 non-null    int64
#  31  Discussion             276 non-null    int64
#  32  Irrelevant             276 non-null    int64
#  33  Location               276 non-null    int64
#  34  priority_level         276 non-null    object
# dtypes: int64(29), object(6)
# memory usage: 77.6+ KB
# None
# 6 trecis2020-A-test.baltimoreFlashFlood2019.csv
# (268, 35)
# Index(['tweet_text', 'user_verified', 'user_followers', 'user_following',
#        'media', 'user_statuses', 'timestamp', 'language', 'location_metadata',
#        'GoodsServices', 'SearchAndRescue', 'InformationWanted', 'Volunteer',
#        'Donations', 'MovePeople', 'FirstPartyObservation',
#        'ThirdPartyObservation', 'Weather', 'EmergingThreats', 'NewSubEvent',
#        'MultimediaShare', 'ServiceAvailable', 'Factoid', 'Official', 'News',
#        'CleanUp', 'Hashtags', 'OriginalEvent', 'ContextualInformation',
#        'Advice', 'Sentiment', 'Discussion', 'Irrelevant', 'Location',
#        'priority_level'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 268 entries, 1157940425879171072 to 1157961073921810432
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_text             268 non-null    object
#  1   user_verified          268 non-null    int64
#  2   user_followers         268 non-null    int64
#  3   user_following         0 non-null      object
#  4   media                  268 non-null    int64
#  5   user_statuses          268 non-null    int64
#  6   timestamp              268 non-null    object
#  7   language               268 non-null    object
#  8   location_metadata      0 non-null      object
#  9   GoodsServices          268 non-null    int64
#  10  SearchAndRescue        268 non-null    int64
#  11  InformationWanted      268 non-null    int64
#  12  Volunteer              268 non-null    int64
#  13  Donations              268 non-null    int64
#  14  MovePeople             268 non-null    int64
#  15  FirstPartyObservation  268 non-null    int64
#  16  ThirdPartyObservation  268 non-null    int64
#  17  Weather                268 non-null    int64
#  18  EmergingThreats        268 non-null    int64
#  19  NewSubEvent            268 non-null    int64
#  20  MultimediaShare        268 non-null    int64
#  21  ServiceAvailable       268 non-null    int64
#  22  Factoid                268 non-null    int64
#  23  Official               268 non-null    int64
#  24  News                   268 non-null    int64
#  25  CleanUp                268 non-null    int64
#  26  Hashtags               268 non-null    int64
#  27  OriginalEvent          268 non-null    int64
#  28  ContextualInformation  268 non-null    int64
#  29  Advice                 268 non-null    int64
#  30  Sentiment              268 non-null    int64
#  31  Discussion             268 non-null    int64
#  32  Irrelevant             268 non-null    int64
#  33  Location               268 non-null    int64
#  34  priority_level         268 non-null    object
# dtypes: int64(29), object(6)
# memory usage: 75.4+ KB
# None
# 7 trecis2020-A-test.hurricaneBarry2019.csv
# (271, 35)
# Index(['tweet_text', 'user_verified', 'user_followers', 'user_following',
#        'media', 'user_statuses', 'timestamp', 'language', 'location_metadata',
#        'GoodsServices', 'SearchAndRescue', 'InformationWanted', 'Volunteer',
#        'Donations', 'MovePeople', 'FirstPartyObservation',
#        'ThirdPartyObservation', 'Weather', 'EmergingThreats', 'NewSubEvent',
#        'MultimediaShare', 'ServiceAvailable', 'Factoid', 'Official', 'News',
#        'CleanUp', 'Hashtags', 'OriginalEvent', 'ContextualInformation',
#        'Advice', 'Sentiment', 'Discussion', 'Irrelevant', 'Location',
#        'priority_level'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 271 entries, 1149693583236227072 to 1149871010231070720
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_text             271 non-null    object
#  1   user_verified          271 non-null    int64
#  2   user_followers         271 non-null    int64
#  3   user_following         0 non-null      object
#  4   media                  271 non-null    int64
#  5   user_statuses          271 non-null    int64
#  6   timestamp              271 non-null    object
#  7   language               271 non-null    object
#  8   location_metadata      0 non-null      object
#  9   GoodsServices          271 non-null    int64
#  10  SearchAndRescue        271 non-null    int64
#  11  InformationWanted      271 non-null    int64
#  12  Volunteer              271 non-null    int64
#  13  Donations              271 non-null    int64
#  14  MovePeople             271 non-null    int64
#  15  FirstPartyObservation  271 non-null    int64
#  16  ThirdPartyObservation  271 non-null    int64
#  17  Weather                271 non-null    int64
#  18  EmergingThreats        271 non-null    int64
#  19  NewSubEvent            271 non-null    int64
#  20  MultimediaShare        271 non-null    int64
#  21  ServiceAvailable       271 non-null    int64
#  22  Factoid                271 non-null    int64
#  23  Official               271 non-null    int64
#  24  News                   271 non-null    int64
#  25  CleanUp                271 non-null    int64
#  26  Hashtags               271 non-null    int64
#  27  OriginalEvent          271 non-null    int64
#  28  ContextualInformation  271 non-null    int64
#  29  Advice                 271 non-null    int64
#  30  Sentiment              271 non-null    int64
#  31  Discussion             271 non-null    int64
#  32  Irrelevant             271 non-null    int64
#  33  Location               271 non-null    int64
#  34  priority_level         271 non-null    object
# dtypes: int64(29), object(6)
# memory usage: 76.2+ KB
# None
# 8 trecis2020-A-test.daytonOhioShooting2019.csv
# (255, 35)
# Index(['tweet_text', 'user_verified', 'user_followers', 'user_following',
#        'media', 'user_statuses', 'timestamp', 'language', 'location_metadata',
#        'GoodsServices', 'SearchAndRescue', 'InformationWanted', 'Volunteer',
#        'Donations', 'MovePeople', 'FirstPartyObservation',
#        'ThirdPartyObservation', 'Weather', 'EmergingThreats', 'NewSubEvent',
#        'MultimediaShare', 'ServiceAvailable', 'Factoid', 'Official', 'News',
#        'CleanUp', 'Hashtags', 'OriginalEvent', 'ContextualInformation',
#        'Advice', 'Sentiment', 'Discussion', 'Irrelevant', 'Location',
#        'priority_level'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 255 entries, 1158161905481125888 to 1158147997106135040
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_text             255 non-null    object
#  1   user_verified          255 non-null    int64
#  2   user_followers         255 non-null    int64
#  3   user_following         0 non-null      object
#  4   media                  255 non-null    int64
#  5   user_statuses          255 non-null    int64
#  6   timestamp              255 non-null    object
#  7   language               255 non-null    object
#  8   location_metadata      0 non-null      object
#  9   GoodsServices          255 non-null    int64
#  10  SearchAndRescue        255 non-null    int64
#  11  InformationWanted      255 non-null    int64
#  12  Volunteer              255 non-null    int64
#  13  Donations              255 non-null    int64
#  14  MovePeople             255 non-null    int64
#  15  FirstPartyObservation  255 non-null    int64
#  16  ThirdPartyObservation  255 non-null    int64
#  17  Weather                255 non-null    int64
#  18  EmergingThreats        255 non-null    int64
#  19  NewSubEvent            255 non-null    int64
#  20  MultimediaShare        255 non-null    int64
#  21  ServiceAvailable       255 non-null    int64
#  22  Factoid                255 non-null    int64
#  23  Official               255 non-null    int64
#  24  News                   255 non-null    int64
#  25  CleanUp                255 non-null    int64
#  26  Hashtags               255 non-null    int64
#  27  OriginalEvent          255 non-null    int64
#  28  ContextualInformation  255 non-null    int64
#  29  Advice                 255 non-null    int64
#  30  Sentiment              255 non-null    int64
#  31  Discussion             255 non-null    int64
#  32  Irrelevant             255 non-null    int64
#  33  Location               255 non-null    int64
#  34  priority_level         255 non-null    object
# dtypes: int64(29), object(6)
# memory usage: 71.7+ KB
# None
# 9 trecis2020-A-test.elPasoWalmartShooting2019.csv
# (262, 35)
# Index(['tweet_text', 'user_verified', 'user_followers', 'user_following',
#        'media', 'user_statuses', 'timestamp', 'language', 'location_metadata',
#        'GoodsServices', 'SearchAndRescue', 'InformationWanted', 'Volunteer',
#        'Donations', 'MovePeople', 'FirstPartyObservation',
#        'ThirdPartyObservation', 'Weather', 'EmergingThreats', 'NewSubEvent',
#        'MultimediaShare', 'ServiceAvailable', 'Factoid', 'Official', 'News',
#        'CleanUp', 'Hashtags', 'OriginalEvent', 'ContextualInformation',
#        'Advice', 'Sentiment', 'Discussion', 'Irrelevant', 'Location',
#        'priority_level'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 262 entries, 1157815279541526528 to 1157817871835324416
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_text             262 non-null    object
#  1   user_verified          262 non-null    int64
#  2   user_followers         262 non-null    int64
#  3   user_following         0 non-null      object
#  4   media                  262 non-null    int64
#  5   user_statuses          262 non-null    int64
#  6   timestamp              262 non-null    object
#  7   language               262 non-null    object
#  8   location_metadata      0 non-null      object
#  9   GoodsServices          262 non-null    int64
#  10  SearchAndRescue        262 non-null    int64
#  11  InformationWanted      262 non-null    int64
#  12  Volunteer              262 non-null    int64
#  13  Donations              262 non-null    int64
#  14  MovePeople             262 non-null    int64
#  15  FirstPartyObservation  262 non-null    int64
#  16  ThirdPartyObservation  262 non-null    int64
#  17  Weather                262 non-null    int64
#  18  EmergingThreats        262 non-null    int64
#  19  NewSubEvent            262 non-null    int64
#  20  MultimediaShare        262 non-null    int64
#  21  ServiceAvailable       262 non-null    int64
#  22  Factoid                262 non-null    int64
#  23  Official               262 non-null    int64
#  24  News                   262 non-null    int64
#  25  CleanUp                262 non-null    int64
#  26  Hashtags               262 non-null    int64
#  27  OriginalEvent          262 non-null    int64
#  28  ContextualInformation  262 non-null    int64
#  29  Advice                 262 non-null    int64
#  30  Sentiment              262 non-null    int64
#  31  Discussion             262 non-null    int64
#  32  Irrelevant             262 non-null    int64
#  33  Location               262 non-null    int64
#  34  priority_level         262 non-null    object
# dtypes: int64(29), object(6)
# memory usage: 73.7+ KB
# None
# 10 trecis2020-A-test.indonesiaEarthquake2019.csv
# (261, 35)
# Index(['tweet_text', 'user_verified', 'user_followers', 'user_following',
#        'media', 'user_statuses', 'timestamp', 'language', 'location_metadata',
#        'GoodsServices', 'SearchAndRescue', 'InformationWanted', 'Volunteer',
#        'Donations', 'MovePeople', 'FirstPartyObservation',
#        'ThirdPartyObservation', 'Weather', 'EmergingThreats', 'NewSubEvent',
#        'MultimediaShare', 'ServiceAvailable', 'Factoid', 'Official', 'News',
#        'CleanUp', 'Hashtags', 'OriginalEvent', 'ContextualInformation',
#        'Advice', 'Sentiment', 'Discussion', 'Irrelevant', 'Location',
#        'priority_level'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 261 entries, 1157335389121548288 to 1157394630561808384
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_text             261 non-null    object
#  1   user_verified          261 non-null    int64
#  2   user_followers         261 non-null    int64
#  3   user_following         0 non-null      object
#  4   media                  261 non-null    int64
#  5   user_statuses          261 non-null    int64
#  6   timestamp              261 non-null    object
#  7   language               261 non-null    object
#  8   location_metadata      0 non-null      object
#  9   GoodsServices          261 non-null    int64
#  10  SearchAndRescue        261 non-null    int64
#  11  InformationWanted      261 non-null    int64
#  12  Volunteer              261 non-null    int64
#  13  Donations              261 non-null    int64
#  14  MovePeople             261 non-null    int64
#  15  FirstPartyObservation  261 non-null    int64
#  16  ThirdPartyObservation  261 non-null    int64
#  17  Weather                261 non-null    int64
#  18  EmergingThreats        261 non-null    int64
#  19  NewSubEvent            261 non-null    int64
#  20  MultimediaShare        261 non-null    int64
#  21  ServiceAvailable       261 non-null    int64
#  22  Factoid                261 non-null    int64
#  23  Official               261 non-null    int64
#  24  News                   261 non-null    int64
#  25  CleanUp                261 non-null    int64
#  26  Hashtags               261 non-null    int64
#  27  OriginalEvent          261 non-null    int64
#  28  ContextualInformation  261 non-null    int64
#  29  Advice                 261 non-null    int64
#  30  Sentiment              261 non-null    int64
#  31  Discussion             261 non-null    int64
#  32  Irrelevant             261 non-null    int64
#  33  Location               261 non-null    int64
#  34  priority_level         261 non-null    object
# dtypes: int64(29), object(6)
# memory usage: 73.4+ KB
# None
# 11 trecis2020-A-test.myanmarFloods2019.csv
# (301, 35)
# Index(['tweet_text', 'user_verified', 'user_followers', 'user_following',
#        'media', 'user_statuses', 'timestamp', 'language', 'location_metadata',
#        'GoodsServices', 'SearchAndRescue', 'InformationWanted', 'Volunteer',
#        'Donations', 'MovePeople', 'FirstPartyObservation',
#        'ThirdPartyObservation', 'Weather', 'EmergingThreats', 'NewSubEvent',
#        'MultimediaShare', 'ServiceAvailable', 'Factoid', 'Official', 'News',
#        'CleanUp', 'Hashtags', 'OriginalEvent', 'ContextualInformation',
#        'Advice', 'Sentiment', 'Discussion', 'Irrelevant', 'Location',
#        'priority_level'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 301 entries, 1160579906910248960 to 1161822253941760000
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_text             301 non-null    object
#  1   user_verified          301 non-null    int64
#  2   user_followers         301 non-null    int64
#  3   user_following         0 non-null      object
#  4   media                  301 non-null    int64
#  5   user_statuses          301 non-null    int64
#  6   timestamp              301 non-null    object
#  7   language               301 non-null    object
#  8   location_metadata      0 non-null      object
#  9   GoodsServices          301 non-null    int64
#  10  SearchAndRescue        301 non-null    int64
#  11  InformationWanted      301 non-null    int64
#  12  Volunteer              301 non-null    int64
#  13  Donations              301 non-null    int64
#  14  MovePeople             301 non-null    int64
#  15  FirstPartyObservation  301 non-null    int64
#  16  ThirdPartyObservation  301 non-null    int64
#  17  Weather                301 non-null    int64
#  18  EmergingThreats        301 non-null    int64
#  19  NewSubEvent            301 non-null    int64
#  20  MultimediaShare        301 non-null    int64
#  21  ServiceAvailable       301 non-null    int64
#  22  Factoid                301 non-null    int64
#  23  Official               301 non-null    int64
#  24  News                   301 non-null    int64
#  25  CleanUp                301 non-null    int64
#  26  Hashtags               301 non-null    int64
#  27  OriginalEvent          301 non-null    int64
#  28  ContextualInformation  301 non-null    int64
#  29  Advice                 301 non-null    int64
#  30  Sentiment              301 non-null    int64
#  31  Discussion             301 non-null    int64
#  32  Irrelevant             301 non-null    int64
#  33  Location               301 non-null    int64
#  34  priority_level         301 non-null    object
# dtypes: int64(29), object(6)
# memory usage: 84.7+ KB
# None
# 12 trecis2020-A-test.brooklynBlockPartyShooting2019.csv
# (285, 35)
# Index(['tweet_text', 'user_verified', 'user_followers', 'user_following',
#        'media', 'user_statuses', 'timestamp', 'language', 'location_metadata',
#        'GoodsServices', 'SearchAndRescue', 'InformationWanted', 'Volunteer',
#        'Donations', 'MovePeople', 'FirstPartyObservation',
#        'ThirdPartyObservation', 'Weather', 'EmergingThreats', 'NewSubEvent',
#        'MultimediaShare', 'ServiceAvailable', 'Factoid', 'Official', 'News',
#        'CleanUp', 'Hashtags', 'OriginalEvent', 'ContextualInformation',
#        'Advice', 'Sentiment', 'Discussion', 'Irrelevant', 'Location',
#        'priority_level'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 285 entries, 1155344649231446016 to 1155426981456097280
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_text             285 non-null    object
#  1   user_verified          285 non-null    int64
#  2   user_followers         285 non-null    int64
#  3   user_following         0 non-null      object
#  4   media                  285 non-null    int64
#  5   user_statuses          285 non-null    int64
#  6   timestamp              285 non-null    object
#  7   language               285 non-null    object
#  8   location_metadata      0 non-null      object
#  9   GoodsServices          285 non-null    int64
#  10  SearchAndRescue        285 non-null    int64
#  11  InformationWanted      285 non-null    int64
#  12  Volunteer              285 non-null    int64
#  13  Donations              285 non-null    int64
#  14  MovePeople             285 non-null    int64
#  15  FirstPartyObservation  285 non-null    int64
#  16  ThirdPartyObservation  285 non-null    int64
#  17  Weather                285 non-null    int64
#  18  EmergingThreats        285 non-null    int64
#  19  NewSubEvent            285 non-null    int64
#  20  MultimediaShare        285 non-null    int64
#  21  ServiceAvailable       285 non-null    int64
#  22  Factoid                285 non-null    int64
#  23  Official               285 non-null    int64
#  24  News                   285 non-null    int64
#  25  CleanUp                285 non-null    int64
#  26  Hashtags               285 non-null    int64
#  27  OriginalEvent          285 non-null    int64
#  28  ContextualInformation  285 non-null    int64
#  29  Advice                 285 non-null    int64
#  30  Sentiment              285 non-null    int64
#  31  Discussion             285 non-null    int64
#  32  Irrelevant             285 non-null    int64
#  33  Location               285 non-null    int64
#  34  priority_level         285 non-null    object
# dtypes: int64(29), object(6)
# memory usage: 80.2+ KB
# None
# 13 trecis2020-A-test.siberianWildfires2019.csv
# (273, 35)
# Index(['tweet_text', 'user_verified', 'user_followers', 'user_following',
#        'media', 'user_statuses', 'timestamp', 'language', 'location_metadata',
#        'GoodsServices', 'SearchAndRescue', 'InformationWanted', 'Volunteer',
#        'Donations', 'MovePeople', 'FirstPartyObservation',
#        'ThirdPartyObservation', 'Weather', 'EmergingThreats', 'NewSubEvent',
#        'MultimediaShare', 'ServiceAvailable', 'Factoid', 'Official', 'News',
#        'CleanUp', 'Hashtags', 'OriginalEvent', 'ContextualInformation',
#        'Advice', 'Sentiment', 'Discussion', 'Irrelevant', 'Location',
#        'priority_level'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 273 entries, 1155616241777876992 to 1156201548663480320
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_text             273 non-null    object
#  1   user_verified          273 non-null    int64
#  2   user_followers         273 non-null    int64
#  3   user_following         0 non-null      object
#  4   media                  273 non-null    int64
#  5   user_statuses          273 non-null    int64
#  6   timestamp              273 non-null    object
#  7   language               273 non-null    object
#  8   location_metadata      0 non-null      object
#  9   GoodsServices          273 non-null    int64
#  10  SearchAndRescue        273 non-null    int64
#  11  InformationWanted      273 non-null    int64
#  12  Volunteer              273 non-null    int64
#  13  Donations              273 non-null    int64
#  14  MovePeople             273 non-null    int64
#  15  FirstPartyObservation  273 non-null    int64
#  16  ThirdPartyObservation  273 non-null    int64
#  17  Weather                273 non-null    int64
#  18  EmergingThreats        273 non-null    int64
#  19  NewSubEvent            273 non-null    int64
#  20  MultimediaShare        273 non-null    int64
#  21  ServiceAvailable       273 non-null    int64
#  22  Factoid                273 non-null    int64
#  23  Official               273 non-null    int64
#  24  News                   273 non-null    int64
#  25  CleanUp                273 non-null    int64
#  26  Hashtags               273 non-null    int64
#  27  OriginalEvent          273 non-null    int64
#  28  ContextualInformation  273 non-null    int64
#  29  Advice                 273 non-null    int64
#  30  Sentiment              273 non-null    int64
#  31  Discussion             273 non-null    int64
#  32  Irrelevant             273 non-null    int64
#  33  Location               273 non-null    int64
#  34  priority_level         273 non-null    object
# dtypes: int64(29), object(6)
# memory usage: 76.8+ KB
# None
# 14 trecis2020-A-test.typhoonKrosa2019.csv
# (303, 35)
# Index(['tweet_text', 'user_verified', 'user_followers', 'user_following',
#        'media', 'user_statuses', 'timestamp', 'language', 'location_metadata',
#        'GoodsServices', 'SearchAndRescue', 'InformationWanted', 'Volunteer',
#        'Donations', 'MovePeople', 'FirstPartyObservation',
#        'ThirdPartyObservation', 'Weather', 'EmergingThreats', 'NewSubEvent',
#        'MultimediaShare', 'ServiceAvailable', 'Factoid', 'Official', 'News',
#        'CleanUp', 'Hashtags', 'OriginalEvent', 'ContextualInformation',
#        'Advice', 'Sentiment', 'Discussion', 'Irrelevant', 'Location',
#        'priority_level'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 303 entries, 1161533617719382016 to 1161444994772656128
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_text             303 non-null    object
#  1   user_verified          303 non-null    int64
#  2   user_followers         303 non-null    int64
#  3   user_following         0 non-null      object
#  4   media                  303 non-null    int64
#  5   user_statuses          303 non-null    int64
#  6   timestamp              303 non-null    object
#  7   language               303 non-null    object
#  8   location_metadata      0 non-null      object
#  9   GoodsServices          303 non-null    int64
#  10  SearchAndRescue        303 non-null    int64
#  11  InformationWanted      303 non-null    int64
#  12  Volunteer              303 non-null    int64
#  13  Donations              303 non-null    int64
#  14  MovePeople             303 non-null    int64
#  15  FirstPartyObservation  303 non-null    int64
#  16  ThirdPartyObservation  303 non-null    int64
#  17  Weather                303 non-null    int64
#  18  EmergingThreats        303 non-null    int64
#  19  NewSubEvent            303 non-null    int64
#  20  MultimediaShare        303 non-null    int64
#  21  ServiceAvailable       303 non-null    int64
#  22  Factoid                303 non-null    int64
#  23  Official               303 non-null    int64
#  24  News                   303 non-null    int64
#  25  CleanUp                303 non-null    int64
#  26  Hashtags               303 non-null    int64
#  27  OriginalEvent          303 non-null    int64
#  28  ContextualInformation  303 non-null    int64
#  29  Advice                 303 non-null    int64
#  30  Sentiment              303 non-null    int64
#  31  Discussion             303 non-null    int64
#  32  Irrelevant             303 non-null    int64
#  33  Location               303 non-null    int64
#  34  priority_level         303 non-null    object
# dtypes: int64(29), object(6)
# memory usage: 85.2+ KB
# None
# 15 trecis2020-A-test.papuaNewguineaEarthquake2019.csv
# (260, 35)
# Index(['tweet_text', 'user_verified', 'user_followers', 'user_following',
#        'media', 'user_statuses', 'timestamp', 'language', 'location_metadata',
#        'GoodsServices', 'SearchAndRescue', 'InformationWanted', 'Volunteer',
#        'Donations', 'MovePeople', 'FirstPartyObservation',
#        'ThirdPartyObservation', 'Weather', 'EmergingThreats', 'NewSubEvent',
#        'MultimediaShare', 'ServiceAvailable', 'Factoid', 'Official', 'News',
#        'CleanUp', 'Hashtags', 'OriginalEvent', 'ContextualInformation',
#        'Advice', 'Sentiment', 'Discussion', 'Irrelevant', 'Location',
#        'priority_level'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 260 entries, 1128328033977470976 to 1128304932652756992
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tweet_text             260 non-null    object
#  1   user_verified          260 non-null    int64
#  2   user_followers         260 non-null    int64
#  3   user_following         0 non-null      object
#  4   media                  260 non-null    int64
#  5   user_statuses          260 non-null    int64
#  6   timestamp              260 non-null    object
#  7   language               260 non-null    object
#  8   location_metadata      0 non-null      object
#  9   GoodsServices          260 non-null    int64
#  10  SearchAndRescue        260 non-null    int64
#  11  InformationWanted      260 non-null    int64
#  12  Volunteer              260 non-null    int64
#  13  Donations              260 non-null    int64
#  14  MovePeople             260 non-null    int64
#  15  FirstPartyObservation  260 non-null    int64
#  16  ThirdPartyObservation  260 non-null    int64
#  17  Weather                260 non-null    int64
#  18  EmergingThreats        260 non-null    int64
#  19  NewSubEvent            260 non-null    int64
#  20  MultimediaShare        260 non-null    int64
#  21  ServiceAvailable       260 non-null    int64
#  22  Factoid                260 non-null    int64
#  23  Official               260 non-null    int64
#  24  News                   260 non-null    int64
#  25  CleanUp                260 non-null    int64
#  26  Hashtags               260 non-null    int64
#  27  OriginalEvent          260 non-null    int64
#  28  ContextualInformation  260 non-null    int64
#  29  Advice                 260 non-null    int64
#  30  Sentiment              260 non-null    int64
#  31  Discussion             260 non-null    int64
#  32  Irrelevant             260 non-null    int64
#  33  Location               260 non-null    int64
#  34  priority_level         260 non-null    object
# dtypes: int64(29), object(6)
# memory usage: 73.1+ KB
# None

# %%
print(len(store))
for i in range(len(file_names)):
  yoman = "__" + file_names[i]
  print(i, yoman)
  store[i].to_csv(yoman)
  files.download(yoman)
# Out:
# 15
# 0 __trecis2020-A-test.whaleyBridgeCollapse2019.csv
# 1 __trecis2020-A-test.gilroygarlicShooting2019.csv
# 2 __trecis2020-A-test.typhoonLekima2019.csv
# 3 __trecis2020-A-test.keralaFloods2019.csv
# 4 __trecis2020-A-test.athensEarthquake2019.csv
# 5 __trecis2020-A-test.baltimoreFlashFlood2019.csv
# 6 __trecis2020-A-test.hurricaneBarry2019.csv
# 7 __trecis2020-A-test.daytonOhioShooting2019.csv
# 8 __trecis2020-A-test.elPasoWalmartShooting2019.csv
# 9 __trecis2020-A-test.indonesiaEarthquake2019.csv
# 10 __trecis2020-A-test.myanmarFloods2019.csv
# 11 __trecis2020-A-test.brooklynBlockPartyShooting2019.csv
# 12 __trecis2020-A-test.siberianWildfires2019.csv
# 13 __trecis2020-A-test.typhoonKrosa2019.csv
# 14 __trecis2020-A-test.papuaNewguineaEarthquake2019.csv
